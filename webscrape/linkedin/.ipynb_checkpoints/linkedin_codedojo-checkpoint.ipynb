# %%
from linkedin_search_posts_bot import *

true=True;false=False
list_of_cookies=[
[
{
    "domain": ".linkedin.com",
    "expirationDate": 1674020108,
    "hostOnly": false,
    "httpOnly": false,
    "name": "_gcl_au",
    "path": "/",
    "sameSite": "unspecified",
    "secure": false,
    "session": false,
    "storeId": "0",
    "value": "1.1.2017951516.1666244109",
    "id": 1
},
{
    "domain": ".linkedin.com",
    "expirationDate": 1674020112.937921,
    "hostOnly": false,
    "httpOnly": false,
    "name": "_guid",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "09b84f30-6d77-4c94-9536-faae54771fe3",
    "id": 2
},
{
    "domain": ".linkedin.com",
    "expirationDate": 1668836131,
    "hostOnly": false,
    "httpOnly": false,
    "name": "aam_uuid",
    "path": "/",
    "sameSite": "unspecified",
    "secure": false,
    "session": false,
    "storeId": "0",
    "value": "48378933371861267413185498925558713753",
    "id": 3
},
{
    "domain": ".linkedin.com",
    "expirationDate": 1681796113,
    "hostOnly": false,
    "httpOnly": false,
    "name": "AMCV_14215E3D5995C57C0A495C55%40AdobeOrg",
    "path": "/",
    "sameSite": "unspecified",
    "secure": false,
    "session": false,
    "storeId": "0",
    "value": "-637568504%7CMCIDTS%7C19286%7CMCMID%7C48944379710023742383240908764049718866%7CMCAAMLH-1666848913%7C3%7CMCAAMB-1666848913%7C6G1ynYcLPuiQxYZrsz_pkqfLG9yMXBpb2zX5dvJdYQJzPXImdj0y%7CMCOPTOUT-1666251313s%7CNONE%7CvVersion%7C5.1.1%7CMCCIDH%7C-1351532375",
    "id": 4
},
{
    "domain": ".linkedin.com",
    "hostOnly": false,
    "httpOnly": false,
    "name": "AMCVS_14215E3D5995C57C0A495C55%40AdobeOrg",
    "path": "/",
    "sameSite": "unspecified",
    "secure": false,
    "session": true,
    "storeId": "0",
    "value": "1",
    "id": 5
},
{
    "domain": ".linkedin.com",
    "expirationDate": 1668836113.157707,
    "hostOnly": false,
    "httpOnly": false,
    "name": "AnalyticsSyncHistory",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "AQLhx-f4x5rVbQAAAYPz43H1A-7-vUB9dZmk-ekXDr4qIzapCW0VYdrRhiviBbmKkmUh3hSeAdAB4ScU3QNZrA",
    "id": 6
},
{
    "domain": ".linkedin.com",
    "expirationDate": 1694064700.46188,
    "hostOnly": false,
    "httpOnly": false,
    "name": "bcookie",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "\"v=2&b155e686-3e5e-43e4-8280-ccd1cf2a05dc\"",
    "id": 7
},
{
    "domain": ".linkedin.com",
    "hostOnly": false,
    "httpOnly": false,
    "name": "lang",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": true,
    "storeId": "0",
    "value": "v=2&lang=en-us",
    "id": 8
},
{
    "domain": ".linkedin.com",
    "expirationDate": 1674020113.637725,
    "hostOnly": false,
    "httpOnly": false,
    "name": "li_sugr",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "71867c49-e2b9-4a6b-8466-31c4b521e632",
    "id": 9
},
{
    "domain": ".linkedin.com",
    "expirationDate": 1674020109.42769,
    "hostOnly": false,
    "httpOnly": false,
    "name": "liap",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "true",
    "id": 10
},
{
    "domain": ".linkedin.com",
    "expirationDate": 1666324787.597896,
    "hostOnly": false,
    "httpOnly": false,
    "name": "lidc",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "\"b=OB53:s=O:r=O:a=O:p=O:g=2872:u=154:x=1:i=1666244114:t=1666324786:v=2:sig=AQFYk896avR9zVCYQsVhxXAkv-a9zpEi\"",
    "id": 11
},
{
    "domain": ".linkedin.com",
    "expirationDate": 1668836113.411775,
    "hostOnly": false,
    "httpOnly": false,
    "name": "lms_ads",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "AQHhBQO_c9R_cwAAAYPz43MRej1st7RQRPyK7ApQ4vlL2jCAIRYA0ShpZEkTS82roptvFDFQQEPo5Ta5W89u4U0pC6BbmNRo",
    "id": 12
},
{
    "domain": ".linkedin.com",
    "expirationDate": 1668836113.411831,
    "hostOnly": false,
    "httpOnly": false,
    "name": "lms_analytics",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "AQHhBQO_c9R_cwAAAYPz43MRej1st7RQRPyK7ApQ4vlL2jCAIRYA0ShpZEkTS82roptvFDFQQEPo5Ta5W89u4U0pC6BbmNRo",
    "id": 13
},
{
    "domain": ".linkedin.com",
    "expirationDate": 1668836113.157692,
    "hostOnly": false,
    "httpOnly": false,
    "name": "UserMatchHistory",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "AQL8_UufhQ5c9QAAAYPz43H1DtCH4gKqSbPlBbPAS_KYpoaODDZQmyZKJo3RKiat6Bff0qFsKbGgSOA_1UBo9o6TFB_Bc6xO-oJOcylTvNRrME8ONYiUp_YTtEkiFgUaNZYNUWZBfrsuUFX6R9lizLqtlghndrb4gMvEugHNwRVz76xIhpJsMOJYOT1RUzfYSbQ1zD9Q2T6RFoO-mwa4QBPUDgx-HePzgCH7n3P0_fPbVAq40G2GN1r14rR095nO-4WPpOCEv2cibGXWusuL4NgvRh3GmtvrNhs63AI",
    "id": 14
},
{
    "domain": ".www.linkedin.com",
    "expirationDate": 1694064700.461916,
    "hostOnly": false,
    "httpOnly": true,
    "name": "bscookie",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "\"v=1&20220907053138e88eca9e-1ac3-4f41-85b9-bf45bd111e69AQE4KdWfVLNdknhX_7c2oF0hyLly4R1D\"",
    "id": 15
},
{
    "domain": ".www.linkedin.com",
    "expirationDate": 1700804107.107454,
    "hostOnly": false,
    "httpOnly": false,
    "name": "G_ENABLED_IDPS",
    "path": "/",
    "sameSite": "unspecified",
    "secure": false,
    "session": false,
    "storeId": "0",
    "value": "google",
    "id": 16
},
{
    "domain": ".www.linkedin.com",
    "expirationDate": 1674020109.427747,
    "hostOnly": false,
    "httpOnly": false,
    "name": "JSESSIONID",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "\"ajax:6367674237908410654\"",
    "id": 17
},
{
    "domain": ".www.linkedin.com",
    "expirationDate": 1697780109.427731,
    "hostOnly": false,
    "httpOnly": true,
    "name": "li_at",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "AQEIACMHHg2cRQAhPxsAAAGD8-NjHwAAAYQX7-cfTQAAAAAAAAAAADBGAiEAh_SPYWp36j-6HG7tZBT-VpPKY8u7blFIj9b9ZnR65ooCIQDhl0niUwomd2MHCnOHOhGYouFWPHIBDNNkWGhMyBkPHYYOaYBOKUADc53FAbMJykWkscoG",
    "id": 18
},
{
    "domain": ".www.linkedin.com",
    "expirationDate": 1697780109.42764,
    "hostOnly": false,
    "httpOnly": true,
    "name": "li_rm",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "AQH-MLvXpan7VQAAAYPz4yizEWStYD-Xb-qY7OU-Uso-0oeUqMyAYIj_HNGJ4Yfrn9lTqUhRiJCY_-CFlnm4ga_yM31lcwxi7p5lr-6p70AWr9f-oLPI0kfX",
    "id": 19
},
{
    "domain": ".www.linkedin.com",
    "expirationDate": 1681796111,
    "hostOnly": false,
    "httpOnly": false,
    "name": "li_theme",
    "path": "/",
    "sameSite": "unspecified",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "light",
    "id": 20
},
{
    "domain": ".www.linkedin.com",
    "expirationDate": 1681796111,
    "hostOnly": false,
    "httpOnly": false,
    "name": "li_theme_set",
    "path": "/",
    "sameSite": "unspecified",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "app",
    "id": 21
},
{
    "domain": ".www.linkedin.com",
    "expirationDate": 1667453711,
    "hostOnly": false,
    "httpOnly": false,
    "name": "timezone",
    "path": "/",
    "sameSite": "unspecified",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "Asia/Singapore",
    "id": 22
}
]]
linkedin.login_cookie(cookies=list_of_cookies)

#please replace the above sample cookies with your cookies, can see below link of how to fetch cookies
linkedin.search_posts(keyword='Code Dojo')

all_data=[]
for i in range(0,3):
	response=linkedin.posts_results()
	data=response['body']
	#data=[{"User Link": "https://www.linkedin.com/in/ACoAAA-o4hwBSDzBqrYMLlBP_Z6a32-3OXHT1JE?lipi=urn%3Ali%3Apage%3Ad_flagship3_search_srp_content%3BeEN9bbddQ0KdHDbJSiRlNw%3D%3D", "Post Text": "My team at Amazon is hiring multiple data scientis.."},..]
	all_data.extend(data)
	linkedin.click_next() # clicks in next button
# Out:
# Progress: 100%|████████████████████████████████████████████████████████████████████| 200.0/200 [00:12<00:00, 16.60it/s]
# Progress:  67%|█████████████████████████████████████████████▎                      | 133.4/200 [00:32<00:19,  3.42it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-5af00e75c46b> in <module>
#     314
#     315 #please replace the above sample cookies with your cookies, can see below link of how to fetch cookies
# --> 316 linkedin.search_posts(keyword='Code Dojo')
#     317
#     318 all_data=[]
#
# ~\anaconda3\lib\site-packages\bot_studio\bot_studio.py in method(*argss, **kwargs)
#     208                             res=modify_res(res,bot)
#     209                             return res
# --> 210                         method=runbot(bot,args)
#     211                     return method
#     212                 return method
#
# ~\anaconda3\lib\site-packages\bot_studio\bot_studio.py in runbot(bot, outputdata)
#     191                             start_time = threading.Timer(3,show_progress, args=(current_user,bot,self.index,serverurl+"fetchbotprogress",))
#     192                             start_time.start()
# --> 193                             res=requests.post(url = url1, data = json.dumps(api_data), headers=headers)
#     194                             res=json.loads(res.text)
#     195                             self.bot=bot
#
# ~\anaconda3\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#     121
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1330         try:
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#    1334                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
all_data
# Out:
# [{'Post Text': 'Home',
#   'User Link': 'https://www.linkedin.com/feed/?doFeedRefresh=true&nis=true&'},
#  {'Post Text': 'My Network',
#   'User Link': 'https://www.linkedin.com/mynetwork/?'},
#  {'Post Text': 'Jobs', 'User Link': 'https://www.linkedin.com/jobs/?'},
#  {'Post Text': 'Messaging',
#   'User Link': 'https://www.linkedin.com/messaging/?'},
#  {'Post Text': 'Notifications',
#   'User Link': 'https://www.linkedin.com/notifications/?'},
#  {'Post Text': 'Me'},
#  {'Post Text': 'Work'},
#  {'Post Text': 'Get Hired Faster, Try Premium Free',
#   'User Link': 'https://www.linkedin.com/premium/products/?family=JSS&upsellOrderOrigin=premium_nav_upsell_text&intentType=SEEK_JOB&utype=job&destRedirectURL=https%3A%2F%2Fwww.linkedin.com%2Ffeed%2F%3FshowPremiumWelcomeBanner%3Dtrue'},
#  {'Post Text': "Who's viewed your profile\n41",
#   'User Link': 'https://www.linkedin.com/me/profile-views/'},
#  {'Post Text': 'Connections\nGrow your network\n223',
#   'User Link': 'https://www.linkedin.com/mynetwork/'},
#  {'Post Text': 'Cloud Computing ➤ Amazon Web Services (AWS) | Azure | Google Cloud | IBM Cloud | Oracle | Alibaba',
#   'User Link': 'https://www.linkedin.com/groups/1346907'},
#  {'Post Text': 'Flutter Developer Community (moderated)',
#   'User Link': 'https://www.linkedin.com/groups/10408911'},
#  {'Post Text': 'Data Science Central',
#   'User Link': 'https://www.linkedin.com/groups/35222'},
#  {'Post Text': 'JavaScript',
#   'User Link': 'https://www.linkedin.com/groups/121615'},
#  {'Post Text': 'Python Developers Community (moderated)',
#   'User Link': 'https://www.linkedin.com/groups/25827'},
#  {'Post Text': 'Cloud Computing ➤ Amazon Web Services (AWS) | Azure | Google Cloud | IBM Cloud | Oracle | Alibaba',
#   'User Link': 'https://www.linkedin.com/groups/1346907'},
#  {'Post Text': 'Flutter Developer Community (moderated)',
#   'User Link': 'https://www.linkedin.com/groups/10408911'},
#  {'Post Text': 'Data Science Central',
#   'User Link': 'https://www.linkedin.com/groups/35222'},
#  {'Post Text': '168\nSarah Tay and 167 others'},
#  {'Post Text': '3 comments'},
#  {'Post Text': '12'},
#  {'Post Text': '440'},
#  {'Post Text': '8 comments'},
#  {'Post Text': '1 repost'},
#  {'Post Text': '3'},
#  {'Post Text': '1 repost'},
#  {'Post Text': '393'},
#  {'Post Text': '13 comments'},
#  {'Post Text': '10 reposts'},
#  {'Post Text': '9,750'},
#  {'Post Text': '115 comments'},
#  {'Post Text': '50 reposts'},
#  {'Post Text': '116\nSarah Tay and 115 others'},
#  {'Post Text': '17 comments'},
#  {'Post Text': 'Kakao co-CEO resigns post outage\n4d ago • 2,062 readers',
#   'User Link': 'https://www.linkedin.com/news/story/kakao-co-ceo-resigns-post-outage-5015993/'},
#  {'Post Text': 'Sunak will be next UK prime minister\n6h ago • 56,198 readers',
#   'User Link': 'https://www.linkedin.com/news/story/sunak-will-be-next-uk-prime-minister-5465492/'},
#  {'Post Text': 'Do you desk-bomb your colleagues?\n3d ago • 488 readers',
#   'User Link': 'https://www.linkedin.com/news/story/do-you-desk-bomb-your-colleagues-5001953/'},
#  {'Post Text': '7 Asian universities in top 50 list\n3d ago • 3,908 readers',
#   'User Link': 'https://www.linkedin.com/news/story/7-asian-universities-in-top-50-list-6024170/'},
#  {'Post Text': 'More flights to ply EU-Asean routes\n5d ago',
#   'User Link': 'https://www.linkedin.com/news/story/more-flights-to-ply-eu-asean-routes-6041050/'},
#  {'Post Text': "Look for interview 'green flags'\n3h ago • 288 readers",
#   'User Link': 'https://www.linkedin.com/news/story/look-for-interview-green-flags-5010033/'},
#  {'Post Text': 'What’s your scariest interview story?\n5d ago • 386 readers',
#   'User Link': 'https://www.linkedin.com/news/story/whats-your-scariest-interview-story-5012225/'},
#  {'Post Text': 'South Korea to embrace digital IDs\n5d ago',
#   'User Link': 'https://www.linkedin.com/news/story/south-korea-to-embrace-digital-ids-5001905/'},
#  {'Post Text': 'SG, EU team up on flying taxis\n4d ago • 128 readers',
#   'User Link': 'https://www.linkedin.com/news/story/sg-eu-team-up-on-flying-taxis-6037642/'},
#  {'Post Text': 'Qualities startup founders look for\n3d ago',
#   'User Link': 'https://www.linkedin.com/news/story/qualities-startup-founders-look-for-5466868/'},
#  {'Post Text': 'About', 'User Link': 'https://about.linkedin.com'},
#  {'Post Text': 'Accessibility',
#   'User Link': 'https://www.linkedin.com/accessibility'},
#  {'Post Text': 'Help Center',
#   'User Link': 'https://www.linkedin.com//help/linkedin?trk=footer_d_flagship3_feed'},
#  {'Post Text': 'Privacy & Terms\nPrivacy Policy\nUser Agreement\nCookie Policy\nCopyright Policy',
#   'User Link': 'https://www.linkedin.com/static?key=user_agreement'},
#  {'Post Text': 'Privacy Policy',
#   'User Link': 'https://www.linkedin.com/static?key=privacy_policy'},
#  {'Post Text': 'User Agreement',
#   'User Link': 'https://www.linkedin.com/static?key=user_agreement'},
#  {'Post Text': 'Cookie Policy',
#   'User Link': 'https://www.linkedin.com/legal/cookie-policy'},
#  {'Post Text': 'Copyright Policy',
#   'User Link': 'https://www.linkedin.com/static?key=copyright_policy'},
#  {'Post Text': 'Ad Choices',
#   'User Link': 'https://www.linkedin.com/help/linkedin/answer/62931'},
#  {'Post Text': 'Advertising',
#   'User Link': 'https://www.linkedin.com/ad/start?trk=n_nav_ads_rr'},
#  {'Post Text': 'Develop talent across your organization',
#   'User Link': 'https://business.linkedin.com/sales-solutions?trk=flagship_nav&veh=li-header-dropdown-lss-control&src=li-nav'},
#  {'Post Text': 'Find, attract and recruit talent',
#   'User Link': 'https://business.linkedin.com/en-sg/talent-solutions?trk=flagship_nav&veh=li-header-dropdown-lts-control-en-sg&src=li-nav'},
#  {'Post Text': 'Unlock sales opportunities',
#   'User Link': 'https://business.linkedin.com/sales-solutions?trk=flagship_nav&veh=li-header-dropdown-lss-control&src=li-nav'},
#  {'Post Text': 'Get your job in front of quality candidates',
#   'User Link': 'https://www.linkedin.com/talent/post-a-job?trk=nav_biz_serv_job_post_nept'},
#  {'Post Text': 'Acquire customers and grow your business',
#   'User Link': 'https://business.linkedin.com/marketing-solutions/ads?trk=n_nav_ads_rr_b&src=li-nav'},
#  {'Post Text': 'Develop talent across your organization',
#   'User Link': 'https://learning.linkedin.com/?trk=d_flagship3_nav&veh=learning_solutions&src=li-nav'},
#  {'Post Text': 'Create a Company Page',
#   'User Link': 'https://www.linkedin.com/company/setup/new/'},
#  {'Post Text': 'Get the LinkedIn app'},
#  {'Post Text': 'More'},
#  {'Post Text': 'Home',
#   'User Link': 'https://www.linkedin.com/feed/?doFeedRefresh=true&nis=true&'},
#  {'Post Text': 'My Network',
#   'User Link': 'https://www.linkedin.com/mynetwork/?'},
#  {'Post Text': 'Jobs', 'User Link': 'https://www.linkedin.com/jobs/?'},
#  {'Post Text': 'Messaging',
#   'User Link': 'https://www.linkedin.com/messaging/?'},
#  {'Post Text': 'Notifications',
#   'User Link': 'https://www.linkedin.com/notifications/?'},
#  {'Post Text': 'Me'},
#  {'Post Text': 'Work'},
#  {'Post Text': 'Get Hired Faster, Try Premium Free',
#   'User Link': 'https://www.linkedin.com/premium/products/?family=JSS&upsellOrderOrigin=premium_nav_upsell_text&intentType=SEEK_JOB&utype=job&destRedirectURL=https%3A%2F%2Fwww.linkedin.com%2Ffeed%2F%3FshowPremiumWelcomeBanner%3Dtrue'},
#  {'Post Text': "Who's viewed your profile\n41",
#   'User Link': 'https://www.linkedin.com/me/profile-views/'},
#  {'Post Text': 'Connections\nGrow your network\n223',
#   'User Link': 'https://www.linkedin.com/mynetwork/'},
#  {'Post Text': 'Cloud Computing ➤ Amazon Web Services (AWS) | Azure | Google Cloud | IBM Cloud | Oracle | Alibaba',
#   'User Link': 'https://www.linkedin.com/groups/1346907'},
#  {'Post Text': 'Flutter Developer Community (moderated)',
#   'User Link': 'https://www.linkedin.com/groups/10408911'},
#  {'Post Text': 'Data Science Central',
#   'User Link': 'https://www.linkedin.com/groups/35222'},
#  {'Post Text': 'JavaScript',
#   'User Link': 'https://www.linkedin.com/groups/121615'},
#  {'Post Text': 'Python Developers Community (moderated)',
#   'User Link': 'https://www.linkedin.com/groups/25827'},
#  {'Post Text': 'Cloud Computing ➤ Amazon Web Services (AWS) | Azure | Google Cloud | IBM Cloud | Oracle | Alibaba',
#   'User Link': 'https://www.linkedin.com/groups/1346907'},
#  {'Post Text': 'Flutter Developer Community (moderated)',
#   'User Link': 'https://www.linkedin.com/groups/10408911'},
#  {'Post Text': 'Data Science Central',
#   'User Link': 'https://www.linkedin.com/groups/35222'},
#  {'Post Text': '168\nSarah Tay and 167 others'},
#  {'Post Text': '3 comments'},
#  {'Post Text': '12'},
#  {'Post Text': '440'},
#  {'Post Text': '8 comments'},
#  {'Post Text': '1 repost'},
#  {'Post Text': '3'},
#  {'Post Text': '1 repost'},
#  {'Post Text': '393'},
#  {'Post Text': '13 comments'},
#  {'Post Text': '10 reposts'},
#  {'Post Text': '9,750'},
#  {'Post Text': '115 comments'},
#  {'Post Text': '50 reposts'},
#  {'Post Text': '116\nSarah Tay and 115 others'},
#  {'Post Text': '17 comments'},
#  {'Post Text': 'Kakao co-CEO resigns post outage\n4d ago • 2,062 readers',
#   'User Link': 'https://www.linkedin.com/news/story/kakao-co-ceo-resigns-post-outage-5015993/'},
#  {'Post Text': 'Sunak will be next UK prime minister\n6h ago • 56,198 readers',
#   'User Link': 'https://www.linkedin.com/news/story/sunak-will-be-next-uk-prime-minister-5465492/'},
#  {'Post Text': 'Do you desk-bomb your colleagues?\n3d ago • 488 readers',
#   'User Link': 'https://www.linkedin.com/news/story/do-you-desk-bomb-your-colleagues-5001953/'},
#  {'Post Text': '7 Asian universities in top 50 list\n3d ago • 3,908 readers',
#   'User Link': 'https://www.linkedin.com/news/story/7-asian-universities-in-top-50-list-6024170/'},
#  {'Post Text': 'More flights to ply EU-Asean routes\n5d ago',
#   'User Link': 'https://www.linkedin.com/news/story/more-flights-to-ply-eu-asean-routes-6041050/'},
#  {'Post Text': "Look for interview 'green flags'\n3h ago • 288 readers",
#   'User Link': 'https://www.linkedin.com/news/story/look-for-interview-green-flags-5010033/'},
#  {'Post Text': 'What’s your scariest interview story?\n5d ago • 386 readers',
#   'User Link': 'https://www.linkedin.com/news/story/whats-your-scariest-interview-story-5012225/'},
#  {'Post Text': 'South Korea to embrace digital IDs\n5d ago',
#   'User Link': 'https://www.linkedin.com/news/story/south-korea-to-embrace-digital-ids-5001905/'},
#  {'Post Text': 'SG, EU team up on flying taxis\n4d ago • 128 readers',
#   'User Link': 'https://www.linkedin.com/news/story/sg-eu-team-up-on-flying-taxis-6037642/'},
#  {'Post Text': 'Qualities startup founders look for\n3d ago',
#   'User Link': 'https://www.linkedin.com/news/story/qualities-startup-founders-look-for-5466868/'},
#  {'Post Text': 'About', 'User Link': 'https://about.linkedin.com'},
#  {'Post Text': 'Accessibility',
#   'User Link': 'https://www.linkedin.com/accessibility'},
#  {'Post Text': 'Help Center',
#   'User Link': 'https://www.linkedin.com//help/linkedin?trk=footer_d_flagship3_feed'},
#  {'Post Text': 'Privacy & Terms\nPrivacy Policy\nUser Agreement\nCookie Policy\nCopyright Policy',
#   'User Link': 'https://www.linkedin.com/static?key=user_agreement'},
#  {'Post Text': 'Privacy Policy',
#   'User Link': 'https://www.linkedin.com/static?key=privacy_policy'},
#  {'Post Text': 'User Agreement',
#   'User Link': 'https://www.linkedin.com/static?key=user_agreement'},
#  {'Post Text': 'Cookie Policy',
#   'User Link': 'https://www.linkedin.com/legal/cookie-policy'},
#  {'Post Text': 'Copyright Policy',
#   'User Link': 'https://www.linkedin.com/static?key=copyright_policy'},
#  {'Post Text': 'Ad Choices',
#   'User Link': 'https://www.linkedin.com/help/linkedin/answer/62931'},
#  {'Post Text': 'Advertising',
#   'User Link': 'https://www.linkedin.com/ad/start?trk=n_nav_ads_rr'},
#  {'Post Text': 'Develop talent across your organization',
#   'User Link': 'https://business.linkedin.com/sales-solutions?trk=flagship_nav&veh=li-header-dropdown-lss-control&src=li-nav'},
#  {'Post Text': 'Find, attract and recruit talent',
#   'User Link': 'https://business.linkedin.com/en-sg/talent-solutions?trk=flagship_nav&veh=li-header-dropdown-lts-control-en-sg&src=li-nav'},
#  {'Post Text': 'Unlock sales opportunities',
#   'User Link': 'https://business.linkedin.com/sales-solutions?trk=flagship_nav&veh=li-header-dropdown-lss-control&src=li-nav'},
#  {'Post Text': 'Get your job in front of quality candidates',
#   'User Link': 'https://www.linkedin.com/talent/post-a-job?trk=nav_biz_serv_job_post_nept'},
#  {'Post Text': 'Acquire customers and grow your business',
#   'User Link': 'https://business.linkedin.com/marketing-solutions/ads?trk=n_nav_ads_rr_b&src=li-nav'},
#  {'Post Text': 'Develop talent across your organization',
#   'User Link': 'https://learning.linkedin.com/?trk=d_flagship3_nav&veh=learning_solutions&src=li-nav'},
#  {'Post Text': 'Create a Company Page',
#   'User Link': 'https://www.linkedin.com/company/setup/new/'},
#  {'Post Text': 'Get the LinkedIn app'},
#  {'Post Text': 'More'},
#  {'Post Text': 'Home',
#   'User Link': 'https://www.linkedin.com/feed/?doFeedRefresh=true&nis=true&'},
#  {'Post Text': 'My Network',
#   'User Link': 'https://www.linkedin.com/mynetwork/?'},
#  {'Post Text': 'Jobs', 'User Link': 'https://www.linkedin.com/jobs/?'},
#  {'Post Text': 'Messaging',
#   'User Link': 'https://www.linkedin.com/messaging/?'},
#  {'Post Text': 'Notifications',
#   'User Link': 'https://www.linkedin.com/notifications/?'},
#  {'Post Text': 'Me'},
#  {'Post Text': 'Work'},
#  {'Post Text': 'Get Hired Faster, Try Premium Free',
#   'User Link': 'https://www.linkedin.com/premium/products/?family=JSS&upsellOrderOrigin=premium_nav_upsell_text&intentType=SEEK_JOB&utype=job&destRedirectURL=https%3A%2F%2Fwww.linkedin.com%2Ffeed%2F%3FshowPremiumWelcomeBanner%3Dtrue'},
#  {'Post Text': "Who's viewed your profile\n41",
#   'User Link': 'https://www.linkedin.com/me/profile-views/'},
#  {'Post Text': 'Connections\nGrow your network\n223',
#   'User Link': 'https://www.linkedin.com/mynetwork/'},
#  {'Post Text': 'Cloud Computing ➤ Amazon Web Services (AWS) | Azure | Google Cloud | IBM Cloud | Oracle | Alibaba',
#   'User Link': 'https://www.linkedin.com/groups/1346907'},
#  {'Post Text': 'Flutter Developer Community (moderated)',
#   'User Link': 'https://www.linkedin.com/groups/10408911'},
#  {'Post Text': 'Data Science Central',
#   'User Link': 'https://www.linkedin.com/groups/35222'},
#  {'Post Text': 'JavaScript',
#   'User Link': 'https://www.linkedin.com/groups/121615'},
#  {'Post Text': 'Python Developers Community (moderated)',
#   'User Link': 'https://www.linkedin.com/groups/25827'},
#  {'Post Text': 'Cloud Computing ➤ Amazon Web Services (AWS) | Azure | Google Cloud | IBM Cloud | Oracle | Alibaba',
#   'User Link': 'https://www.linkedin.com/groups/1346907'},
#  {'Post Text': 'Flutter Developer Community (moderated)',
#   'User Link': 'https://www.linkedin.com/groups/10408911'},
#  {'Post Text': 'Data Science Central',
#   'User Link': 'https://www.linkedin.com/groups/35222'},
#  {'Post Text': '168\nSarah Tay and 167 others'},
#  {'Post Text': '3 comments'},
#  {'Post Text': '12'},
#  {'Post Text': '440'},
#  {'Post Text': '8 comments'},
#  {'Post Text': '1 repost'},
#  {'Post Text': '3'},
#  {'Post Text': '1 repost'},
#  {'Post Text': '393'},
#  {'Post Text': '13 comments'},
#  {'Post Text': '10 reposts'},
#  {'Post Text': '9,750'},
#  {'Post Text': '115 comments'},
#  {'Post Text': '50 reposts'},
#  {'Post Text': '116\nSarah Tay and 115 others'},
#  {'Post Text': '17 comments'},
#  {'Post Text': 'Kakao co-CEO resigns post outage\n4d ago • 2,062 readers',
#   'User Link': 'https://www.linkedin.com/news/story/kakao-co-ceo-resigns-post-outage-5015993/'},
#  {'Post Text': 'Sunak will be next UK prime minister\n6h ago • 56,198 readers',
#   'User Link': 'https://www.linkedin.com/news/story/sunak-will-be-next-uk-prime-minister-5465492/'},
#  {'Post Text': 'Do you desk-bomb your colleagues?\n3d ago • 488 readers',
#   'User Link': 'https://www.linkedin.com/news/story/do-you-desk-bomb-your-colleagues-5001953/'},
#  {'Post Text': '7 Asian universities in top 50 list\n3d ago • 3,908 readers',
#   'User Link': 'https://www.linkedin.com/news/story/7-asian-universities-in-top-50-list-6024170/'},
#  {'Post Text': 'More flights to ply EU-Asean routes\n5d ago',
#   'User Link': 'https://www.linkedin.com/news/story/more-flights-to-ply-eu-asean-routes-6041050/'},
#  {'Post Text': "Look for interview 'green flags'\n3h ago • 288 readers",
#   'User Link': 'https://www.linkedin.com/news/story/look-for-interview-green-flags-5010033/'},
#  {'Post Text': 'What’s your scariest interview story?\n5d ago • 386 readers',
#   'User Link': 'https://www.linkedin.com/news/story/whats-your-scariest-interview-story-5012225/'},
#  {'Post Text': 'South Korea to embrace digital IDs\n5d ago',
#   'User Link': 'https://www.linkedin.com/news/story/south-korea-to-embrace-digital-ids-5001905/'},
#  {'Post Text': 'SG, EU team up on flying taxis\n4d ago • 128 readers',
#   'User Link': 'https://www.linkedin.com/news/story/sg-eu-team-up-on-flying-taxis-6037642/'},
#  {'Post Text': 'Qualities startup founders look for\n3d ago',
#   'User Link': 'https://www.linkedin.com/news/story/qualities-startup-founders-look-for-5466868/'},
#  {'Post Text': 'About', 'User Link': 'https://about.linkedin.com'},
#  {'Post Text': 'Accessibility',
#   'User Link': 'https://www.linkedin.com/accessibility'},
#  {'Post Text': 'Help Center',
#   'User Link': 'https://www.linkedin.com//help/linkedin?trk=footer_d_flagship3_feed'},
#  {'Post Text': 'Privacy & Terms\nPrivacy Policy\nUser Agreement\nCookie Policy\nCopyright Policy',
#   'User Link': 'https://www.linkedin.com/static?key=user_agreement'},
#  {'Post Text': 'Privacy Policy',
#   'User Link': 'https://www.linkedin.com/static?key=privacy_policy'},
#  {'Post Text': 'User Agreement',
#   'User Link': 'https://www.linkedin.com/static?key=user_agreement'},
#  {'Post Text': 'Cookie Policy',
#   'User Link': 'https://www.linkedin.com/legal/cookie-policy'},
#  {'Post Text': 'Copyright Policy',
#   'User Link': 'https://www.linkedin.com/static?key=copyright_policy'},
#  {'Post Text': 'Ad Choices',
#   'User Link': 'https://www.linkedin.com/help/linkedin/answer/62931'},
#  {'Post Text': 'Advertising',
#   'User Link': 'https://www.linkedin.com/ad/start?trk=n_nav_ads_rr'},
#  {'Post Text': 'Develop talent across your organization',
#   'User Link': 'https://business.linkedin.com/sales-solutions?trk=flagship_nav&veh=li-header-dropdown-lss-control&src=li-nav'},
#  {'Post Text': 'Find, attract and recruit talent',
#   'User Link': 'https://business.linkedin.com/en-sg/talent-solutions?trk=flagship_nav&veh=li-header-dropdown-lts-control-en-sg&src=li-nav'},
#  {'Post Text': 'Unlock sales opportunities',
#   'User Link': 'https://business.linkedin.com/sales-solutions?trk=flagship_nav&veh=li-header-dropdown-lss-control&src=li-nav'},
#  {'Post Text': 'Get your job in front of quality candidates',
#   'User Link': 'https://www.linkedin.com/talent/post-a-job?trk=nav_biz_serv_job_post_nept'},
#  {'Post Text': 'Acquire customers and grow your business',
#   'User Link': 'https://business.linkedin.com/marketing-solutions/ads?trk=n_nav_ads_rr_b&src=li-nav'},
#  {'Post Text': 'Develop talent across your organization',
#   'User Link': 'https://learning.linkedin.com/?trk=d_flagship3_nav&veh=learning_solutions&src=li-nav'},
#  {'Post Text': 'Create a Company Page',
#   'User Link': 'https://www.linkedin.com/company/setup/new/'},
#  {'Post Text': 'Get the LinkedIn app'},
#  {'Post Text': 'More'}]

# %%
useful_data = []
for data in all_data:
    if (len(data) > 1 and len(data['Post Text']) > 50):
        useful_data.append(data['Post Text'])

# %%
useful_data
# Out:
# ['Adi HuzaimiView Adi Huzaimi’s profile\nOut of network\n·\xa03rd+\nCustomer Relationship Management\nMessage',
#  'John ChenView John Chen’s profile\nOut of network\n·\xa03rd+\nCloud Learning | Sales & Partner Enablement | Global Onboarding | Ex-Google | ACLP | PMP® | CSPO® | ITIL® | UX | PDPA\nFollow',
#  'Enjie LeeView Enjie Lee’s profile\nOut of network\n·\xa03rd+\nBusiness Development Representative @ simPRO software | Helping field service teams to improve efficiency and increase profit | Saas\nFollow',
#  'Gitanjali KumarView Gitanjali Kumar’s profile\nOut of network\n·\xa03rd+\nSales Consultant\nMessage',
#  'Josephine Agatha HemingwayView Josephine Agatha Hemingway’s profile\n2nd degree connection\n·\xa02nd\nFinal Year NTU Data Science & AI | Founder @ TBP\nConnect\nConnect',
#  'Bao LeView Bao Le’s profile\nOut of network\n·\xa03rd+\nSoftware Engineering Internship at Holistics Data\nMessage',
#  'Yi Yang, PhDView Yi Yang, PhD’s profile\nOut of network\n·\xa03rd+\nUser experience researcher\nMessage',
#  'Teck Lung NgView Teck Lung Ng’s profile\nOut of network\n·\xa03rd+\nSalesforce Certified Administrator\nMessage',
#  'Charlene H.View Charlene H.’s profile\nOut of network\n·\xa03rd+\nSenior UX Researcher in Ninjavan\nFollow',
#  'Alvin PangView Alvin Pang’s profile\nOut of network\n·\xa03rd+\nProject Manager\nMessage',
#  'Status is reachable\nBenjamin TanView Benjamin Tan’s profile\n• 1st1st degree connection\n• 1st1st degree connection\nPenultimate Student @ Singapore Management University, Information Systems\nSingapore\nRafael J. Barros, Lee Jin, and 28 other mutual connections\nMessage',
#  'Past: Software Engineering Intern at Kopi Date - ...personalised promo-code. Upon successful signup...',
#  'Honors & Awards: 4th Place - Ninja Van Code Dojo Hackathon',
#  'Code Dojo é uma Escola de Tecnologia que utiliza metodologia autoral e hands-on, de forma que todas as técnicas e ferramentas utilizadas permitem que você consiga aplicar o aprendido antes mesmo de terminar o curso.  Cursos desenvolvidos de forma personalizada e com conteúdo atualizado, seguindo as tendências e...',
#  'Our programs empower kids with the tool to express themselves in cool and creative ways!',
#  'The past year with Ninja Van has been an incredible journey! For me, it’s honestly the people and opportunities I am given that made the experience with the company tremendously fulfilling. 🙌🏼🎊Sat down and reflected on the victories over the past year, I gotta admit that it wasn’t easy but made possible with the people that I have met. It was hard work learning the ropes from scratch with close to zero HR background. But a significant portion of my growth came from the people that I get to learn, interact and work alongside with. 🔥Over the year, I had the opportunity to build these programme/projects.1) Orchestrated Ninja Van’s inaugural external Hackathon (Code Dojo 22).2) Engaged with partnering companies like Google Cloud for Campus initiatives.3) Collaborated with Senior Tech Management team to implement changes in our recruitment process.4) Partnered with Hiring Managers to ensure organisational manpower needs were met across the region.5) Fostered as close knitted SE intern community which resulted in a great internship/employee engagement.6) Directed recruitment and engagements initiatives with local campuses.Non of these achievements would have been possible without the mentorship and guidance of my Tech HR Team lead by Wesley Ng and my team members Jessica Chuah & Nazurah Zakaria who so patiently showed me the way to grow. Special shout out to Karen Tay or being my trusted branding partner 🙏🏼 who is always with me for the engagements! Also my Regional HR department with the friendship, advices and laughter filled lunches, It never gets boring with plenty of things to talk about every week.Huge kudos goes out to Shaun Chong and his whole team for helping me learn more about the tech industry and it’s nuances! Love the team energy and culture and for accepting me as your own team member. Edison Mok for being such an amazing partner from Google Cloud with the spontaneity when it comes to our collaboration!My key takeaway for the year is about being the hardest worker in the room. When we are entrusted with tasks, the ball is our court to deliver. In my time with Ninja Van, It was never about perfection but how precise the execution can be with whatever resources we are given. I believe that we never fail, we only learn. The notion of learning is core in Ninja Van and I am glad to be a part of what the company have to offer! Onwards to more victories and learning opportunity with everyone here!#opportunity #experience #growth #management #tech #learning #hr #people #recruitment\n…see more',
#  "This time last week, Greg G Tan, Keng Swee Teo, Tan Jie En, and I took on the challenge of Google Cloud x Ninja Van's inaugural hackathon, aptly named Code Dojo 2022!It was a tough 36 hours, as we tried to balance our time between classes, exam revisions, and the hackathon itself. I'd love to tell everyone how we handled our time perfectly but truthfully, many of us were busy coding throughout our classes and exam revisions were out of the picture until a day before our midterms.Nevertheless, the event has been extremely fulfilling; as we gained insights into what it takes to become a leading innovative logistics provider. I guess in a way, whatever content we missed in class, we had also made up with invaluable experience.I'm proud to share that at the end of the hackathon, we clinched 1st in Code Dojo 2022. Beyond hard work, teamwork played an equally crucial role in our win — we were able to leverage each other's strengths to build a full-stack application within a short span of time. More importantly, we had loads of fun while we were at it!I've included our pitch deck in this post, hope you guys like it!#hackathon #googlecloudplatform #codedojo #teamworkmakesdreamwork #ninjavan\n…see more",
#  "We're so excited to share that registrations for our Hackathon, NINJA VAN CODE DOJO 2022 is now open!! Gather your friends and sign up today :DPaul Aw Yao Feng Jessica Chuah Wesley Ng#NinjaVan #NinjaTech #Hackathon #tech\n…see more",
#  'Status is offline\nBrian WongView Brian Wong’s profile\n• 2nd2nd degree connection\n• 2nd2nd degree connection\nPenultimate NUS Business Analytics Undergraduate | NUS Fintech Society Machine Learning Analyst\nSingapore\nShuang Wang is a mutual connection\nConnect',
#  'Honors & Awards: Ninja Van Code Dojo 2022 Certificate of Participation',
#  'Certifications: Coding for Beginners 1: You Can Learn to Code!',
#  "Current: Founder, Stick 'Em at Stick 'Em - TLDR: STEAM education is too damn expensive, and not everyone knows how to code. Our hypothesis...",
#  'Past: Software Engineer at ST Engineering - -Web development (Defence) -Javascript (dojo) -Work with MSSQL stored procedure -Develop a new Web...',
#  'Adi HuzaimiView Adi Huzaimi’s profile\nOut of network\n·\xa03rd+\nCustomer Relationship Management\nMessage',
#  'John ChenView John Chen’s profile\nOut of network\n·\xa03rd+\nCloud Learning | Sales & Partner Enablement | Global Onboarding | Ex-Google | ACLP | PMP® | CSPO® | ITIL® | UX | PDPA\nFollow',
#  'Enjie LeeView Enjie Lee’s profile\nOut of network\n·\xa03rd+\nBusiness Development Representative @ simPRO software | Helping field service teams to improve efficiency and increase profit | Saas\nFollow',
#  'Gitanjali KumarView Gitanjali Kumar’s profile\nOut of network\n·\xa03rd+\nSales Consultant\nMessage',
#  'Josephine Agatha HemingwayView Josephine Agatha Hemingway’s profile\n2nd degree connection\n·\xa02nd\nFinal Year NTU Data Science & AI | Founder @ TBP\nConnect\nConnect',
#  'Bao LeView Bao Le’s profile\nOut of network\n·\xa03rd+\nSoftware Engineering Internship at Holistics Data\nMessage',
#  'Yi Yang, PhDView Yi Yang, PhD’s profile\nOut of network\n·\xa03rd+\nUser experience researcher\nMessage',
#  'Teck Lung NgView Teck Lung Ng’s profile\nOut of network\n·\xa03rd+\nSalesforce Certified Administrator\nMessage',
#  'Charlene H.View Charlene H.’s profile\nOut of network\n·\xa03rd+\nSenior UX Researcher in Ninjavan\nFollow',
#  'Alvin PangView Alvin Pang’s profile\nOut of network\n·\xa03rd+\nProject Manager\nMessage',
#  'Status is reachable\nBenjamin TanView Benjamin Tan’s profile\n• 1st1st degree connection\n• 1st1st degree connection\nPenultimate Student @ Singapore Management University, Information Systems\nSingapore\nRafael J. Barros, Lee Jin, and 28 other mutual connections\nMessage',
#  'Past: Software Engineering Intern at Kopi Date - ...personalised promo-code. Upon successful signup...',
#  'Honors & Awards: 4th Place - Ninja Van Code Dojo Hackathon',
#  'Code Dojo é uma Escola de Tecnologia que utiliza metodologia autoral e hands-on, de forma que todas as técnicas e ferramentas utilizadas permitem que você consiga aplicar o aprendido antes mesmo de terminar o curso.  Cursos desenvolvidos de forma personalizada e com conteúdo atualizado, seguindo as tendências e...',
#  'Our programs empower kids with the tool to express themselves in cool and creative ways!',
#  'The past year with Ninja Van has been an incredible journey! For me, it’s honestly the people and opportunities I am given that made the experience with the company tremendously fulfilling. 🙌🏼🎊Sat down and reflected on the victories over the past year, I gotta admit that it wasn’t easy but made possible with the people that I have met. It was hard work learning the ropes from scratch with close to zero HR background. But a significant portion of my growth came from the people that I get to learn, interact and work alongside with. 🔥Over the year, I had the opportunity to build these programme/projects.1) Orchestrated Ninja Van’s inaugural external Hackathon (Code Dojo 22).2) Engaged with partnering companies like Google Cloud for Campus initiatives.3) Collaborated with Senior Tech Management team to implement changes in our recruitment process.4) Partnered with Hiring Managers to ensure organisational manpower needs were met across the region.5) Fostered as close knitted SE intern community which resulted in a great internship/employee engagement.6) Directed recruitment and engagements initiatives with local campuses.Non of these achievements would have been possible without the mentorship and guidance of my Tech HR Team lead by Wesley Ng and my team members Jessica Chuah & Nazurah Zakaria who so patiently showed me the way to grow. Special shout out to Karen Tay or being my trusted branding partner 🙏🏼 who is always with me for the engagements! Also my Regional HR department with the friendship, advices and laughter filled lunches, It never gets boring with plenty of things to talk about every week.Huge kudos goes out to Shaun Chong and his whole team for helping me learn more about the tech industry and it’s nuances! Love the team energy and culture and for accepting me as your own team member. Edison Mok for being such an amazing partner from Google Cloud with the spontaneity when it comes to our collaboration!My key takeaway for the year is about being the hardest worker in the room. When we are entrusted with tasks, the ball is our court to deliver. In my time with Ninja Van, It was never about perfection but how precise the execution can be with whatever resources we are given. I believe that we never fail, we only learn. The notion of learning is core in Ninja Van and I am glad to be a part of what the company have to offer! Onwards to more victories and learning opportunity with everyone here!#opportunity #experience #growth #management #tech #learning #hr #people #recruitment\n…see more',
#  "This time last week, Greg G Tan, Keng Swee Teo, Tan Jie En, and I took on the challenge of Google Cloud x Ninja Van's inaugural hackathon, aptly named Code Dojo 2022!It was a tough 36 hours, as we tried to balance our time between classes, exam revisions, and the hackathon itself. I'd love to tell everyone how we handled our time perfectly but truthfully, many of us were busy coding throughout our classes and exam revisions were out of the picture until a day before our midterms.Nevertheless, the event has been extremely fulfilling; as we gained insights into what it takes to become a leading innovative logistics provider. I guess in a way, whatever content we missed in class, we had also made up with invaluable experience.I'm proud to share that at the end of the hackathon, we clinched 1st in Code Dojo 2022. Beyond hard work, teamwork played an equally crucial role in our win — we were able to leverage each other's strengths to build a full-stack application within a short span of time. More importantly, we had loads of fun while we were at it!I've included our pitch deck in this post, hope you guys like it!#hackathon #googlecloudplatform #codedojo #teamworkmakesdreamwork #ninjavan\n…see more",
#  "We're so excited to share that registrations for our Hackathon, NINJA VAN CODE DOJO 2022 is now open!! Gather your friends and sign up today :DPaul Aw Yao Feng Jessica Chuah Wesley Ng#NinjaVan #NinjaTech #Hackathon #tech\n…see more",
#  'Status is offline\nBrian WongView Brian Wong’s profile\n• 2nd2nd degree connection\n• 2nd2nd degree connection\nPenultimate NUS Business Analytics Undergraduate | NUS Fintech Society Machine Learning Analyst\nSingapore\nShuang Wang is a mutual connection\nConnect',
#  'Honors & Awards: Ninja Van Code Dojo 2022 Certificate of Participation',
#  'Certifications: Coding for Beginners 1: You Can Learn to Code!',
#  "Current: Founder, Stick 'Em at Stick 'Em - TLDR: STEAM education is too damn expensive, and not everyone knows how to code. Our hypothesis...",
#  'Past: Software Engineer at ST Engineering - -Web development (Defence) -Javascript (dojo) -Work with MSSQL stored procedure -Develop a new Web...',
#  'Adi HuzaimiView Adi Huzaimi’s profile\nOut of network\n·\xa03rd+\nCustomer Relationship Management\nMessage',
#  'John ChenView John Chen’s profile\nOut of network\n·\xa03rd+\nCloud Learning | Sales & Partner Enablement | Global Onboarding | Ex-Google | ACLP | PMP® | CSPO® | ITIL® | UX | PDPA\nFollow',
#  'Enjie LeeView Enjie Lee’s profile\nOut of network\n·\xa03rd+\nBusiness Development Representative @ simPRO software | Helping field service teams to improve efficiency and increase profit | Saas\nFollow',
#  'Gitanjali KumarView Gitanjali Kumar’s profile\nOut of network\n·\xa03rd+\nSales Consultant\nMessage',
#  'Josephine Agatha HemingwayView Josephine Agatha Hemingway’s profile\n2nd degree connection\n·\xa02nd\nFinal Year NTU Data Science & AI | Founder @ TBP\nConnect\nConnect',
#  'Bao LeView Bao Le’s profile\nOut of network\n·\xa03rd+\nSoftware Engineering Internship at Holistics Data\nMessage',
#  'Yi Yang, PhDView Yi Yang, PhD’s profile\nOut of network\n·\xa03rd+\nUser experience researcher\nMessage',
#  'Teck Lung NgView Teck Lung Ng’s profile\nOut of network\n·\xa03rd+\nSalesforce Certified Administrator\nMessage',
#  'Charlene H.View Charlene H.’s profile\nOut of network\n·\xa03rd+\nSenior UX Researcher in Ninjavan\nFollow',
#  'Alvin PangView Alvin Pang’s profile\nOut of network\n·\xa03rd+\nProject Manager\nMessage',
#  'Status is reachable\nBenjamin TanView Benjamin Tan’s profile\n• 1st1st degree connection\n• 1st1st degree connection\nPenultimate Student @ Singapore Management University, Information Systems\nSingapore\nRafael J. Barros, Lee Jin, and 28 other mutual connections\nMessage',
#  'Past: Software Engineering Intern at Kopi Date - ...personalised promo-code. Upon successful signup...',
#  'Honors & Awards: 4th Place - Ninja Van Code Dojo Hackathon',
#  'Code Dojo é uma Escola de Tecnologia que utiliza metodologia autoral e hands-on, de forma que todas as técnicas e ferramentas utilizadas permitem que você consiga aplicar o aprendido antes mesmo de terminar o curso.  Cursos desenvolvidos de forma personalizada e com conteúdo atualizado, seguindo as tendências e...',
#  'Our programs empower kids with the tool to express themselves in cool and creative ways!',
#  'The past year with Ninja Van has been an incredible journey! For me, it’s honestly the people and opportunities I am given that made the experience with the company tremendously fulfilling. 🙌🏼🎊Sat down and reflected on the victories over the past year, I gotta admit that it wasn’t easy but made possible with the people that I have met. It was hard work learning the ropes from scratch with close to zero HR background. But a significant portion of my growth came from the people that I get to learn, interact and work alongside with. 🔥Over the year, I had the opportunity to build these programme/projects.1) Orchestrated Ninja Van’s inaugural external Hackathon (Code Dojo 22).2) Engaged with partnering companies like Google Cloud for Campus initiatives.3) Collaborated with Senior Tech Management team to implement changes in our recruitment process.4) Partnered with Hiring Managers to ensure organisational manpower needs were met across the region.5) Fostered as close knitted SE intern community which resulted in a great internship/employee engagement.6) Directed recruitment and engagements initiatives with local campuses.Non of these achievements would have been possible without the mentorship and guidance of my Tech HR Team lead by Wesley Ng and my team members Jessica Chuah & Nazurah Zakaria who so patiently showed me the way to grow. Special shout out to Karen Tay or being my trusted branding partner 🙏🏼 who is always with me for the engagements! Also my Regional HR department with the friendship, advices and laughter filled lunches, It never gets boring with plenty of things to talk about every week.Huge kudos goes out to Shaun Chong and his whole team for helping me learn more about the tech industry and it’s nuances! Love the team energy and culture and for accepting me as your own team member. Edison Mok for being such an amazing partner from Google Cloud with the spontaneity when it comes to our collaboration!My key takeaway for the year is about being the hardest worker in the room. When we are entrusted with tasks, the ball is our court to deliver. In my time with Ninja Van, It was never about perfection but how precise the execution can be with whatever resources we are given. I believe that we never fail, we only learn. The notion of learning is core in Ninja Van and I am glad to be a part of what the company have to offer! Onwards to more victories and learning opportunity with everyone here!#opportunity #experience #growth #management #tech #learning #hr #people #recruitment\n…see more',
#  "This time last week, Greg G Tan, Keng Swee Teo, Tan Jie En, and I took on the challenge of Google Cloud x Ninja Van's inaugural hackathon, aptly named Code Dojo 2022!It was a tough 36 hours, as we tried to balance our time between classes, exam revisions, and the hackathon itself. I'd love to tell everyone how we handled our time perfectly but truthfully, many of us were busy coding throughout our classes and exam revisions were out of the picture until a day before our midterms.Nevertheless, the event has been extremely fulfilling; as we gained insights into what it takes to become a leading innovative logistics provider. I guess in a way, whatever content we missed in class, we had also made up with invaluable experience.I'm proud to share that at the end of the hackathon, we clinched 1st in Code Dojo 2022. Beyond hard work, teamwork played an equally crucial role in our win — we were able to leverage each other's strengths to build a full-stack application within a short span of time. More importantly, we had loads of fun while we were at it!I've included our pitch deck in this post, hope you guys like it!#hackathon #googlecloudplatform #codedojo #teamworkmakesdreamwork #ninjavan\n…see more",
#  "We're so excited to share that registrations for our Hackathon, NINJA VAN CODE DOJO 2022 is now open!! Gather your friends and sign up today :DPaul Aw Yao Feng Jessica Chuah Wesley Ng#NinjaVan #NinjaTech #Hackathon #tech\n…see more",
#  'Status is offline\nBrian WongView Brian Wong’s profile\n• 2nd2nd degree connection\n• 2nd2nd degree connection\nPenultimate NUS Business Analytics Undergraduate | NUS Fintech Society Machine Learning Analyst\nSingapore\nShuang Wang is a mutual connection\nConnect',
#  'Honors & Awards: Ninja Van Code Dojo 2022 Certificate of Participation',
#  'Certifications: Coding for Beginners 1: You Can Learn to Code!',
#  "Current: Founder, Stick 'Em at Stick 'Em - TLDR: STEAM education is too damn expensive, and not everyone knows how to code. Our hypothesis...",
#  'Past: Software Engineer at ST Engineering - -Web development (Defence) -Javascript (dojo) -Work with MSSQL stored procedure -Develop a new Web...']

# %%
import pandas as pd
linkedin_df = pd.DataFrame(useful_data, columns=['Post'])
linkedin_df.to_csv("linkedin_code_dojo.csv")

# %% [markdown]
# # New

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager

import sys
import csv
import time

# import the webdriver
chrome_options = Options()
chrome_options.headless = False
chrome_options.add_argument("start-maximized")
#chrome_options.addArguments("disable-infobars");

 
# Creating a webdriver instance
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
# This instance will be used to log into LinkedIn
 
# Opening linkedIn's login page
driver.get("https://linkedin.com/uas/login")
 
# waiting for the page to load
time.sleep(5)
 
# entering username
username = driver.find_element(By.XPATH, "//input[contains(@id, 'username')]")
 
# In case of an error, try changing the element
# tag used here.
 
# Enter Your Email Address
username.send_keys("") 
 
# entering password
pword = driver.find_element(By.XPATH, "//input[contains(@id, 'password')]")
# In case of an error, try changing the element
# tag used here.
 
# Enter Your Password
pword.send_keys("")       
 
# Clicking on the log in button
# Format (syntax) of writing XPath -->
# //tagname[@attribute='value']
driver.find_element(By.XPATH, "//button[contains(@class, 'btn__primary--large from__button--floating')]").click()
# In case of an error, try changing the
# XPath used here.

#Search
search = driver.find_element(By.XPATH, "//input[contains(@class, 'search-global-typeahead__input always-show-placeholder')]")
search.send_keys("Code Dojo Ninja van")
search.send_keys(Keys.ENTER)

time.sleep(5)
#Post button
button = driver.find_elements(By.XPATH, "//button[contains(@class, 'artdeco-pill')]")
button[0].click()

#scroll
last_height = driver.execute_script("return document.body.scrollHeight")
while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
    # Wait to load page
    time.sleep(2)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

store=[]
container = driver.find_elements(By.XPATH, "//div[contains(@class, 'feed-shared-update-v2 feed-shared-update-v2--minimal-padding full-height relative')]")
#posts = driver.find_elements(By.XPATH, "//div[contains(@class, 'update-components-text relative feed-shared-update-v2__commentary')]")
#print(posts)
for i in range(len(container)):
    try:
        #print(posts[i].text)
        #store.append(posts[i].text.replace("\n", "  "))
        temp_dict = {}
        post = container[i].find_element(By.XPATH, ".//div[contains(@class, 'update-components-text relative feed-shared-update-v2__commentary')]").text.replace("\n", "  ")
        background = container[i].find_element(By.XPATH, ".//span[contains(@class, 'feed-shared-actor__description')]").text.replace("\n", "  ")
        #print(background)
        temp_dict['post'] = post
        temp_dict['background'] = background
        store.append(temp_dict)
    except:
        pass
driver.quit()

# %%
store
# Out:
# [{'post': "In February this year, Ninja Van's office space was bustling with energy as we held our inaugural 36 Hour hackathon! (Original Post: https://lnkd.in/gRxyQc2s)    The hackathon started off with an Operations Immersion followed by workshops hosted by Google Cloud's engineers. Participants of the hackathon also had the opportunity to interact with our Software Engineers as well as Product Managers to gain better insights into the solutions they prepared.    Here's a 3-minute video recap reliving the exciting moments we had during the hackathon! You can also hear advice from , Co-founder and CTO of Ninja Van Group, , Regional Director and CTO of South East Asia and Partners at APAC, Google Cloud and , CEO, SP Digital.",
#   'background': 'Software Engineer'},
#  {'post': "We're so excited to share that registrations for our Hackathon, NINJA VAN CODE DOJO 2022 is now open!! Gather your friends and sign up today :D",
#   'background': 'Regional Senior Specialist, Talent Acquisition (Technology) at Ninja Van'},
#  {'post': "My friends Tran Linh Chi, SOPHIA MARANI and I participated as Team Jolibeeee in Ninja Van's Code Dojo 22 and spent our Thursday and Friday brainstorming and developing our solution. We developed a Telegram chatbot that could be integrated into Ninjava's existing platform that would help tackle the communication issues between the drivers and the higher chain of command whenever the driver faced sudden disruptions during delivery. Potential iterations could include Voice to text NLP as well as analytics to aid in route planning and parcel delivery optimization.    Even though we did not place in the finals (we were so close), we had a unique and fun experience in Ninjavan. We'd like to thank the organizers involved for filling us up with a constant stream of food, coffee, and energy drinks and the handmade oven kilned pizzas (which severely raised our pizza standards), to the PMs for patiently answering all our questions, and to especially to for constantly bugging us to sign up.    From a ninjaboo to a ninjawoo with team jolibeee!",
#   'background': 'Final Year@SMU | President@SMUWiT | Full Stack Developer'},
#  {'post': 'We are one week away from Code Dojo 2022, Ninja Van’s inaugural 36-hour hackathon.     A huge thank you to everyone who’s submitted your application! We’ve been blown away by the number of entries this year. Lucky for us, we’ve got an expert panel of judges who cannot wait to experience the brilliance of each team’s innovative solutions.    Meet your Code Dojo 2022 judges...',
#   'background': '75,464 followers'},
#  {'post': 'Code Dojo 22, Ninja Van’s inaugural hackathon is underway!    Our participants have just finished their operations immersion programme where they had firsthand experience of what happens behind the scenes of our operations.    From parcel scanning to sorting and preparing routes for the deliveries, the full-day programme hopes to get participants familiar with our last-mile delivery experience in order to gain insights into how they can develop unique solutions to improve some of our logistical challenges.    The theme for this year’s hackathon is: How would you deliver to our shippers, drivers and parcel recipients?    Stay tuned for more as Code Dojo 22 unfolds in the next 3 days!',
#   'background': '75,464 followers'},
#  {'post': "In the latter half of last week, Ninja Van's multi-purpose office space was abuzz with energy as 15 teams joined our inaugural 36-hour #hackathon Code Dojo 22, with some of them joining us virtually.    To better equip the participants for the hackathon, we conducted a series of workshops and networking sessions. , our partner and sponsor, kicked off the session by sharing with participants more about Google's platform and how the different tools can be implemented in their solution for the hackathon.    Participants also had the opportunity to speak to Ninja Van's Product Managers and Software Engineers to gain better insights into some of our logistical challenges before they started to code their solutions.    The top three teams received cash prizes and to add to the excitement, a lucky few also walked away with fabulous prizes.    “I hope that the participants learnt how to bootstrap and create a MVP (Minimal Viable Product) in these 36 hours. I am impressed at the result as it was a difficult task but made possible with new and modern technology available on the Google Cloud platform. To participants, I hope that all of you had much fun at Code Dojo 22, and have drawn much learning and insights to inspire you to continue creating. ” — , Co-founder and Chief Technology Officer, Ninja Van Group.    We'd like to thank all our judges , Regional Director and CTO of South East Asia and Partners at APAC, Google Cloud and , CEO, SP Digital and participants for making this a successful event. Until next year!      ",
#   'background': '75,464 followers'}]

# %%
csv_file = "linkedin_code_dojo.csv"
try:
    with open(csv_file, 'w') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=['post','background'])
        writer.writeheader()
        for data in store:
            writer.writerow(data)
except IOError:
    print("I/O error")
