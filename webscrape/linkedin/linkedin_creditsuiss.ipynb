# %%
from linkedin_search_posts_bot import *

true=True;false=False
list_of_cookies=[
[
{
    "domain": ".linkedin.com",
    "expirationDate": 1674020108,
    "hostOnly": false,
    "httpOnly": false,
    "name": "_gcl_au",
    "path": "/",
    "sameSite": "unspecified",
    "secure": false,
    "session": false,
    "storeId": "0",
    "value": "1.1.2017951516.1666244109",
    "id": 1
},
{
    "domain": ".linkedin.com",
    "expirationDate": 1674020112.937921,
    "hostOnly": false,
    "httpOnly": false,
    "name": "_guid",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "09b84f30-6d77-4c94-9536-faae54771fe3",
    "id": 2
},
{
    "domain": ".linkedin.com",
    "expirationDate": 1668836131,
    "hostOnly": false,
    "httpOnly": false,
    "name": "aam_uuid",
    "path": "/",
    "sameSite": "unspecified",
    "secure": false,
    "session": false,
    "storeId": "0",
    "value": "48378933371861267413185498925558713753",
    "id": 3
},
{
    "domain": ".linkedin.com",
    "expirationDate": 1681796113,
    "hostOnly": false,
    "httpOnly": false,
    "name": "AMCV_14215E3D5995C57C0A495C55%40AdobeOrg",
    "path": "/",
    "sameSite": "unspecified",
    "secure": false,
    "session": false,
    "storeId": "0",
    "value": "-637568504%7CMCIDTS%7C19286%7CMCMID%7C48944379710023742383240908764049718866%7CMCAAMLH-1666848913%7C3%7CMCAAMB-1666848913%7C6G1ynYcLPuiQxYZrsz_pkqfLG9yMXBpb2zX5dvJdYQJzPXImdj0y%7CMCOPTOUT-1666251313s%7CNONE%7CvVersion%7C5.1.1%7CMCCIDH%7C-1351532375",
    "id": 4
},
{
    "domain": ".linkedin.com",
    "hostOnly": false,
    "httpOnly": false,
    "name": "AMCVS_14215E3D5995C57C0A495C55%40AdobeOrg",
    "path": "/",
    "sameSite": "unspecified",
    "secure": false,
    "session": true,
    "storeId": "0",
    "value": "1",
    "id": 5
},
{
    "domain": ".linkedin.com",
    "expirationDate": 1668836113.157707,
    "hostOnly": false,
    "httpOnly": false,
    "name": "AnalyticsSyncHistory",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "AQLhx-f4x5rVbQAAAYPz43H1A-7-vUB9dZmk-ekXDr4qIzapCW0VYdrRhiviBbmKkmUh3hSeAdAB4ScU3QNZrA",
    "id": 6
},
{
    "domain": ".linkedin.com",
    "expirationDate": 1694064700.46188,
    "hostOnly": false,
    "httpOnly": false,
    "name": "bcookie",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "\"v=2&b155e686-3e5e-43e4-8280-ccd1cf2a05dc\"",
    "id": 7
},
{
    "domain": ".linkedin.com",
    "hostOnly": false,
    "httpOnly": false,
    "name": "lang",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": true,
    "storeId": "0",
    "value": "v=2&lang=en-us",
    "id": 8
},
{
    "domain": ".linkedin.com",
    "expirationDate": 1674020113.637725,
    "hostOnly": false,
    "httpOnly": false,
    "name": "li_sugr",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "71867c49-e2b9-4a6b-8466-31c4b521e632",
    "id": 9
},
{
    "domain": ".linkedin.com",
    "expirationDate": 1674020109.42769,
    "hostOnly": false,
    "httpOnly": false,
    "name": "liap",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "true",
    "id": 10
},
{
    "domain": ".linkedin.com",
    "expirationDate": 1666324787.597896,
    "hostOnly": false,
    "httpOnly": false,
    "name": "lidc",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "\"b=OB53:s=O:r=O:a=O:p=O:g=2872:u=154:x=1:i=1666244114:t=1666324786:v=2:sig=AQFYk896avR9zVCYQsVhxXAkv-a9zpEi\"",
    "id": 11
},
{
    "domain": ".linkedin.com",
    "expirationDate": 1668836113.411775,
    "hostOnly": false,
    "httpOnly": false,
    "name": "lms_ads",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "AQHhBQO_c9R_cwAAAYPz43MRej1st7RQRPyK7ApQ4vlL2jCAIRYA0ShpZEkTS82roptvFDFQQEPo5Ta5W89u4U0pC6BbmNRo",
    "id": 12
},
{
    "domain": ".linkedin.com",
    "expirationDate": 1668836113.411831,
    "hostOnly": false,
    "httpOnly": false,
    "name": "lms_analytics",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "AQHhBQO_c9R_cwAAAYPz43MRej1st7RQRPyK7ApQ4vlL2jCAIRYA0ShpZEkTS82roptvFDFQQEPo5Ta5W89u4U0pC6BbmNRo",
    "id": 13
},
{
    "domain": ".linkedin.com",
    "expirationDate": 1668836113.157692,
    "hostOnly": false,
    "httpOnly": false,
    "name": "UserMatchHistory",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "AQL8_UufhQ5c9QAAAYPz43H1DtCH4gKqSbPlBbPAS_KYpoaODDZQmyZKJo3RKiat6Bff0qFsKbGgSOA_1UBo9o6TFB_Bc6xO-oJOcylTvNRrME8ONYiUp_YTtEkiFgUaNZYNUWZBfrsuUFX6R9lizLqtlghndrb4gMvEugHNwRVz76xIhpJsMOJYOT1RUzfYSbQ1zD9Q2T6RFoO-mwa4QBPUDgx-HePzgCH7n3P0_fPbVAq40G2GN1r14rR095nO-4WPpOCEv2cibGXWusuL4NgvRh3GmtvrNhs63AI",
    "id": 14
},
{
    "domain": ".www.linkedin.com",
    "expirationDate": 1694064700.461916,
    "hostOnly": false,
    "httpOnly": true,
    "name": "bscookie",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "\"v=1&20220907053138e88eca9e-1ac3-4f41-85b9-bf45bd111e69AQE4KdWfVLNdknhX_7c2oF0hyLly4R1D\"",
    "id": 15
},
{
    "domain": ".www.linkedin.com",
    "expirationDate": 1700804107.107454,
    "hostOnly": false,
    "httpOnly": false,
    "name": "G_ENABLED_IDPS",
    "path": "/",
    "sameSite": "unspecified",
    "secure": false,
    "session": false,
    "storeId": "0",
    "value": "google",
    "id": 16
},
{
    "domain": ".www.linkedin.com",
    "expirationDate": 1674020109.427747,
    "hostOnly": false,
    "httpOnly": false,
    "name": "JSESSIONID",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "\"ajax:6367674237908410654\"",
    "id": 17
},
{
    "domain": ".www.linkedin.com",
    "expirationDate": 1697780109.427731,
    "hostOnly": false,
    "httpOnly": true,
    "name": "li_at",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "AQEIACMHHg2cRQAhPxsAAAGD8-NjHwAAAYQX7-cfTQAAAAAAAAAAADBGAiEAh_SPYWp36j-6HG7tZBT-VpPKY8u7blFIj9b9ZnR65ooCIQDhl0niUwomd2MHCnOHOhGYouFWPHIBDNNkWGhMyBkPHYYOaYBOKUADc53FAbMJykWkscoG",
    "id": 18
},
{
    "domain": ".www.linkedin.com",
    "expirationDate": 1697780109.42764,
    "hostOnly": false,
    "httpOnly": true,
    "name": "li_rm",
    "path": "/",
    "sameSite": "no_restriction",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "AQH-MLvXpan7VQAAAYPz4yizEWStYD-Xb-qY7OU-Uso-0oeUqMyAYIj_HNGJ4Yfrn9lTqUhRiJCY_-CFlnm4ga_yM31lcwxi7p5lr-6p70AWr9f-oLPI0kfX",
    "id": 19
},
{
    "domain": ".www.linkedin.com",
    "expirationDate": 1681796111,
    "hostOnly": false,
    "httpOnly": false,
    "name": "li_theme",
    "path": "/",
    "sameSite": "unspecified",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "light",
    "id": 20
},
{
    "domain": ".www.linkedin.com",
    "expirationDate": 1681796111,
    "hostOnly": false,
    "httpOnly": false,
    "name": "li_theme_set",
    "path": "/",
    "sameSite": "unspecified",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "app",
    "id": 21
},
{
    "domain": ".www.linkedin.com",
    "expirationDate": 1667453711,
    "hostOnly": false,
    "httpOnly": false,
    "name": "timezone",
    "path": "/",
    "sameSite": "unspecified",
    "secure": true,
    "session": false,
    "storeId": "0",
    "value": "Asia/Singapore",
    "id": 22
}
]]
linkedin.login_cookie(cookies=list_of_cookies)

#please replace the above sample cookies with your cookies, can see below link of how to fetch cookies
linkedin.search_posts(keyword='Credit Suisse Coding Challenge')

all_data=[]
continue_run = True
for i in range(0,20):
	response=linkedin.posts_results()
	data=response['body']
	#data=[{"User Link": "https://www.linkedin.com/in/ACoAAA-o4hwBSDzBqrYMLlBP_Z6a32-3OXHT1JE?lipi=urn%3Ali%3Apage%3Ad_flagship3_search_srp_content%3BeEN9bbddQ0KdHDbJSiRlNw%3D%3D", "Post Text": "My team at Amazon is hiring multiple data scientis.."},..]
	all_data.extend(data)
	linkedin.click_next() # clicks in next button
# Out:
# Progress: 100%|██████████| 200.0/200 [00:14<00:00, 14.25it/s]
# Progress: 100%|██████████| 200.0/200 [01:06<00:00,  3.02it/s]
# Progress: 100%|██████████| 200.0/200 [00:12<00:00, 16.60it/s]
# Progress: 100%|██████████| 200/200 [00:12<00:00, 16.63it/s]
# Progress: 100%|██████████| 200.0/200 [00:14<00:00, 14.14it/s]
# Progress: 100%|██████████| 200/200 [00:02<00:00, 99.69it/s]
# Progress: 100%|██████████| 200.0/200 [00:12<00:00, 16.58it/s]
# Progress: 100%|██████████| 200/200 [00:04<00:00, 49.89it/s]
# Progress: 100%|██████████| 200.0/200 [00:12<00:00, 16.61it/s]
# Progress: 100%|██████████| 200/200 [00:12<00:00, 16.63it/s]
# Progress: 100%|██████████| 200.0/200 [00:14<00:00, 14.18it/s]
# Progress: 100%|██████████| 200/200 [00:02<00:00, 99.72it/s]
# Progress: 100%|██████████| 200.0/200 [00:12<00:00, 16.61it/s]
# Progress: 100%|██████████| 200/200 [00:12<00:00, 16.63it/s]
# Progress: 100%|██████████| 200.0/200 [00:14<00:00, 14.13it/s]
# ...

# %%
all_data
# Out:
# [{'Post Text': 'Home',
#   'User Link': 'https://www.linkedin.com/feed/?nis=true&'},
#  {'Post Text': 'My Network',
#   'User Link': 'https://www.linkedin.com/mynetwork/?'},
#  {'Post Text': 'Jobs', 'User Link': 'https://www.linkedin.com/jobs/?'},
#  {'Post Text': 'Messaging',
#   'User Link': 'https://www.linkedin.com/messaging/?'},
#  {'Post Text': '33 new notifications\nNotifications',
#   'User Link': 'https://www.linkedin.com/notifications/?'},
#  {'Post Text': 'Me'},
#  {'Post Text': 'Work'},
#  {'Post Text': 'Try Premium for free',
#   'User Link': 'https://www.linkedin.com/premium/products/?upsellOrderOrigin=premium_nav_upsell_text&destRedirectURL=https%3A%2F%2Fwww.linkedin.com%2Ffeed%2F%3FshowPremiumWelcomeBanner%3Dtrue'},
#  {'Post Text': ''},
#  {'Post Text': ''},
#  {'Post Text': ''},
#  {'Post Text': ''},
#  {'Post Text': ''},
#  {'Post Text': ''},
#  {'Post Text': ''},
#  {'Post Text': ''},
#  {'Post Text': ''},
#  {'Post Text': ''},
#  {'Post Text': ''},
# ...

# %%
useful_data = []
for data in all_data:
    if (len(data) > 1 and len(data['Post Text']) > 50):
        useful_data.append(data['Post Text'])

# %%
useful_data
# Out:
# ['From getting disqualified for unknown reasons, to landing in the second position, the journey wasn’t easy but it was worth it at the end. Sometimes you gotta fight for something you deserve.Hello, Connections.I hope you are doing well. Last year, I won the Global Coding Challenge organized by Credit Suisse from the rest of the world region, and this year I landed in the second position. It wasn’t easy for me because I was disqualified, as my solution for problem 4 matched with someone else’s. I have posted my solution as well here.Finally, I would like to congratulate my friend Bibek Panthi and am glad to share that the top two positions are from Tribhuvan University. Congratulations to us!!!#coding #university',
# ...

# %%
import pandas as pd
linkedin_df = pd.DataFrame(useful_data, columns=['Post'])
linkedin_df.to_csv("credit_suisse_hackathon.csv")
# Out:
# Progress: 100%|██████████| 200/200 [00:04<00:00, 49.88it/s]

# %% [markdown]
# # Selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager

import sys
import csv
import time

# import the webdriver
chrome_options = Options()
chrome_options.headless = False
chrome_options.add_argument("start-maximized")
#chrome_options.addArguments("disable-infobars");

 
# Creating a webdriver instance
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
# This instance will be used to log into LinkedIn
 
# Opening linkedIn's login page
driver.get("https://linkedin.com/uas/login")
 
# waiting for the page to load
time.sleep(5)
 
# entering username
username = driver.find_element(By.XPATH, "//input[contains(@id, 'username')]")
 
# In case of an error, try changing the element
# tag used here.
 
# Enter Your Email Address
username.send_keys("") 
 
# entering password
pword = driver.find_element(By.XPATH, "//input[contains(@id, 'password')]")
# In case of an error, try changing the element
# tag used here.
 
# Enter Your Password
pword.send_keys("")       
 
# Clicking on the log in button
# Format (syntax) of writing XPath -->
# //tagname[@attribute='value']
driver.find_element(By.XPATH, "//button[contains(@class, 'btn__primary--large from__button--floating')]").click()
# In case of an error, try changing the
# XPath used here.

#Search
search = driver.find_element(By.XPATH, "//input[contains(@class, 'search-global-typeahead__input always-show-placeholder')]")
search.send_keys("Credit Suisse Coding Challenge")
search.send_keys(Keys.ENTER)

time.sleep(5)
#Post button
button = driver.find_elements(By.XPATH, "//button[contains(@class, 'artdeco-pill')]")
button[0].click()
#print(button)

#scroll
last_height = driver.execute_script("return document.body.scrollHeight")
while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
    # Wait to load page
    time.sleep(2)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(5)
store=[]
#posts = driver.find_elements(By.XPATH, "//div[contains(@class, 'update-components-text relative feed-shared-update-v2__commentary')]")
container = driver.find_elements(By.XPATH, "//div[contains(@class, 'feed-shared-update-v2 feed-shared-update-v2--minimal-padding full-height relative')]")

#print(posts)
for i in range(len(container)):
    try:
        #print(posts[i].text)
        #store.append(posts[i].text.replace("\n", "  "))
        temp_dict = {}
        post = container[i].find_element(By.XPATH, ".//div[contains(@class, 'update-components-text relative feed-shared-update-v2__commentary')]").text.replace("\n", "  ")
        background = container[i].find_element(By.XPATH, ".//span[contains(@class, 'feed-shared-actor__description')]").text.replace("\n", "  ")
        #print(background)
        temp_dict['post'] = post
        temp_dict['background'] = background
        store.append(temp_dict)
    except:
        pass
driver.quit()

# %%
store
# Out:
# [{'post': 'Last weekend, Perlyn Chew, Ryan Wong and I took part in the Credit Suisse CodeIT Challenge 2022. We came in 1st, and had lots of fun working on the coding challenges. Great job team and thank you Credit Suisse for organising such a wonderful event!',
#   'background': 'Computer Science Undergraduate at NUS'},
# ...

# %%
csv_file = "credit_suisse_hackathon_selenium.csv"
try:
    with open(csv_file, 'w') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=['post','background'])
        writer.writeheader()
        for data in store:
            writer.writerow(data)
except IOError:
    print("I/O error")
