# %%
# Import packages
import nltk
from pprint import pprint
import yaml
import sys
import os
import re
import pandas as pd

dict_tagged_sentences = ''
# Below indicates the relative path to
# positive/negative/inverter/incrementer/decrementer files
DICTIONARY_DIR_PREFIX = '../dicts/'

import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\ZY\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
dell = pd.read_csv('../../../scrapy-hackathon/webscrape/linkedin/credit_suisse_hackathon_selenium.csv')
sentiment_analysis_creditS = pd.DataFrame(dell)
sentiment_analysis_creditS = sentiment_analysis_creditS['post']
sentiment_analysis_creditS[1]
# Out:
# 'FIS in India is proud to announce the successful completion of CODE FEST 2022.  The event was hosted virtually over a period of two months and 1500 participants worked on specific challenges and leveraged skills such as Java and .Net to develop innovative solutions for the challenges given to them. We had 100+ coding challenge qualifiers from companies like Google, Amazon, Adobe, Morgan Stanley, Walmart, KPMG, Credit Suisse, Deloitte, and Oracle, and the top 3 winners were announced in a virtual award ceremony in presence of our leaders. Many congratulations to all the winners and participants and special thanks to our event hosting partner Mercer Mettl and all our colleagues for their support. Meet the winners:'

# %%
class Splitter(object):
    def __init__(self):
        self.nltk_splitter = nltk.data.load('tokenizers/punkt/english.pickle')
        self.nltk_tokenizer = nltk.tokenize.TreebankWordTokenizer()

    def split(self, text):
        """
        input format: a paragraph of text
        output format: a list of lists of words.
            e.g.: [['this', 'is', 'a', 'sentence'], ['this', 'is', 'another', 'one']]
        """
        sentences = self.nltk_splitter.tokenize(text)
        tokenized_sentences = [self.nltk_tokenizer.tokenize(sent) for sent in sentences]
        return tokenized_sentences


class POSTagger(object):
    def __init__(self):
        pass

    def pos_tag(self, sentences):
        """
        input format: list of lists of words
            e.g.: [['this', 'is', 'a', 'sentence'], ['this', 'is', 'another', 'one']]
        output format: list of lists of tagged tokens. Each tagged tokens has a
        form, a lemma, and a list of tags
            e.g: [[('this', 'this', ['DT']), ('is', 'be', ['VB']), ('a', 'a', ['DT']), ('sentence', 'sentence', ['NN'])],
                    [('this', 'this', ['DT']), ('is', 'be', ['VB']), ('another', 'another', ['DT']), ('one', 'one', ['CARD'])]]
        """

        pos = [nltk.pos_tag(sentence) for sentence in sentences]
        #adapt format
        pos = [[(word, word, [postag]) for (word, postag) in sentence] for sentence in pos]
        return pos

class DictionaryTagger(object):
    def __init__(self, dictionary_paths):
        """

        :rtype : object
        """
        files = [open(path, 'r') for path in dictionary_paths]
        dictionaries = [yaml.full_load(dict_file) for dict_file in files]
        #print(dictionaries)
        map(lambda x: x.close(), files)
        self.dictionary = {}
        self.max_key_size = 0
        for curr_dict in dictionaries:
            for key in curr_dict:
                #print(key)
                if key in self.dictionary:
                    self.dictionary[key].extend(curr_dict[key])
                else:
                    #print(len(key))
                    self.dictionary[key] = curr_dict[key]
                    self.max_key_size = max(self.max_key_size, len(key))

    def tag(self, postagged_sentences):
        return [self.tag_sentence(sentence) for sentence in postagged_sentences]

    def tag_sentence(self, sentence, tag_with_lemmas=False):
        """
        the result is only one tagging of all the possible ones.
        The resulting tagging is determined by these two priority rules:
            - longest matches have higher priority
            - search is made from left to right
        """
        tag_sentence = []
        N = len(sentence)
        if self.max_key_size == 0:
            self.max_key_size = N
        i = 0
        while (i < N):
            j = min(i + self.max_key_size, N) #avoid overflow
            tagged = False
            while (j > i):
                expression_form = ' '.join([word[0] for word in sentence[i:j]]).lower()
                expression_lemma = ' '.join([word[1] for word in sentence[i:j]]).lower()
                if tag_with_lemmas:
                    literal = expression_lemma
                else:
                    literal = expression_form
                if literal in self.dictionary:
                    #self.logger.debug("found: %s" % literal)
                    is_single_token = j - i == 1
                    original_position = i
                    i = j
                    taggings = [tag for tag in self.dictionary[literal]]
                    tagged_expression = (expression_form, expression_lemma, taggings)
                    if is_single_token: #if the tagged literal is a single token, conserve its previous taggings:
                        original_token_tagging = sentence[original_position][2]
                        tagged_expression[2].extend(original_token_tagging)
                    tag_sentence.append(tagged_expression)
                    tagged = True
                else:
                    j = j - 1
            if not tagged:
                tag_sentence.append(sentence[i])
                i += 1
        return tag_sentence

def value_of(sentiment):
    if sentiment == 'positive': return 1
    if sentiment == 'negative': return -1
    return 0

def sentiment_score(review):
    return sum ([value_of(tag) for sentence in dict_tagged_sentences for token in sentence for tag in token[2]])

def sentence_score(sentence_tokens, previous_token, acum_score):
    if not sentence_tokens:
        return acum_score
    else:
        current_token = sentence_tokens[0]
        tags = current_token[2]
        token_score = sum([value_of(tag) for tag in tags])
        if previous_token is not None:
            previous_tags = previous_token[2]
            if 'inc' in previous_tags:
                token_score *= 2.0
            elif 'dec' in previous_tags:
                token_score /= 2.0
            elif 'inv' in previous_tags:
                token_score *= -1.0
        return sentence_score(sentence_tokens[1:], current_token, acum_score + token_score)

def sentiment_score(sentences):
    return sum([sentence_score(sentence, None, 0.0) for sentence in sentences])


def run_analysis(text):
    splitter = Splitter() # This boy will split a long single string into sentences.
    postagger = POSTagger() # This boy is the Part-Of-Speech tagger.

    # If text contains multiple sentences, this line splits it into individual sentences.
    splitted_sentences = splitter.split(text)
    #print (splitted_sentences)
    #exit(1)

    #print ("########## This performs Part-Of-Speech tagging. ##########")
    # This performs Part-Of-Speech tagging.
    pos_tagged_sentences = postagger.pos_tag(splitted_sentences)
    #pprint (pos_tagged_sentences)
    #exit(1)

    # print ("########## This line loads Positive word and Negative word lexicons. ##########")
    # # This line loads Positive word and Negative word lexicons.
    # dicttagger = DictionaryTagger([ DICTIONARY_DIR_PREFIX + 'positive.yml', DICTIONARY_DIR_PREFIX + 'negative.yml'])
    # dict_tagged_sentences = dicttagger.tag(pos_tagged_sentences)
    # print(dict_tagged_sentences)
    # #exit(1)

    # print ("########## [Baseline Analysis] Using only Positive/Negative lexicon. ##########")
    # score = sentiment_score(dict_tagged_sentences)
    # print ("Score: %d" % score)
    # #exit(1)

    # print ("########## This line loads Positve/Negative lexicon + incrementer/decrementer lexicon. ##########")
    # dicttagger = DictionaryTagger([ DICTIONARY_DIR_PREFIX + 'positive.yml', DICTIONARY_DIR_PREFIX + 'negative.yml', DICTIONARY_DIR_PREFIX + 'inc.yml', DICTIONARY_DIR_PREFIX + 'dec.yml'])
    # dict_tagged_sentences = dicttagger.tag(pos_tagged_sentences)
    # pprint(dict_tagged_sentences)
    # score = sentiment_score(dict_tagged_sentences)
    # print ("Score: %d" % score)
    # #exit(1)

    #print ("########## This line loads Positve/Negative lexicon + incrementer/decrementer/inverter lexicon. ##########")
    dicttagger = DictionaryTagger([ DICTIONARY_DIR_PREFIX + 'positive.yml', DICTIONARY_DIR_PREFIX + 'negative.yml', DICTIONARY_DIR_PREFIX + 'inc.yml', DICTIONARY_DIR_PREFIX + 'dec.yml', DICTIONARY_DIR_PREFIX + 'inv.yml'])
    dict_tagged_sentences = dicttagger.tag(pos_tagged_sentences)
    pprint(dict_tagged_sentences)
    score = sentiment_score(dict_tagged_sentences)
    #print ("Score: %d" % score)
    return score
    #exit(1)

# %%
################### This is the MAIN section ###################
if __name__ == "__main__":

    #print ("###############################")

    sentiment_array = []
    total_score = 0
    length = len(sentiment_analysis_creditS)
    for post in sentiment_analysis_creditS:
        #print ("###############################")
        # Run sentiment scoring
        score = run_analysis(post)
        if (score == 0):
            sentiment_array.append("Neutral")
        elif (score > 0 and score < 6):
            sentiment_array.append("Positive")
        elif (score >= 6):
            sentiment_array.append("Very Positive")
        elif (score < 0):
            sentiment_array.append("Negative")
        total_score += score
    average_score = total_score/length
    # Run sentiment scoring
# Out:
# [[('Last', 'Last', ['JJ']),
#   ('weekend', 'weekend', ['NN']),
#   (',', ',', [',']),
#   ('Perlyn', 'Perlyn', ['NNP']),
#   ('Chew', 'Chew', ['NNP']),
#   (',', ',', [',']),
#   ('Ryan', 'Ryan', ['NNP']),
#   ('Wong', 'Wong', ['NNP']),
#   ('and', 'and', ['CC']),
#   ('I', 'I', ['PRP']),
#   ('took', 'took', ['VBD']),
#   ('part', 'part', ['NN']),
#   ('in', 'in', ['IN']),
#   ('the', 'the', ['DT']),
#   ('Credit', 'Credit', ['NNP']),
#   ('Suisse', 'Suisse', ['NNP']),
#   ('CodeIT', 'CodeIT', ['NNP']),
#   ('Challenge', 'Challenge', ['NNP']),
#   ('2022', '2022', ['CD']),
#   ('.', '.', ['.'])],
#  [('We', 'We', ['PRP']),
#   ('came', 'came', ['VBD']),
#   ('in', 'in', ['IN']),
#   ('1st', '1st', ['CD']),
#   (',', ',', [',']),
#   ('and', 'and', ['CC']),
#   ('had', 'had', ['VBD']),
#   ('lots', 'lots', ['NNS']),
#   ('of', 'of', ['IN']),
#   ('fun', 'fun', ['positive', 'NN']),
#   ('working', 'working', ['VBG']),
#   ('on', 'on', ['IN']),
#   ('the', 'the', ['DT']),
#   ('coding', 'coding', ['NN']),
#   ('challenges', 'challenges', ['NNS']),
#   ('.', '.', ['.'])],
#  [('great', 'great', ['positive', 'NNP']),
#   ('job', 'job', ['NN']),
#   ('team', 'team', ['NN']),
#   ('and', 'and', ['CC']),
#   ('thank', 'thank', ['positive', 'NN']),
#   ('you', 'you', ['PRP']),
#   ('Credit', 'Credit', ['NNP']),
#   ('Suisse', 'Suisse', ['NNP']),
#   ('for', 'for', ['IN']),
#   ('organising', 'organising', ['VBG']),
#   ('such', 'such', ['PDT']),
#   ('a', 'a', ['DT']),
#   ('wonderful', 'wonderful', ['positive', 'JJ']),
#   ('event', 'event', ['NN']),
#   ('!', '!', ['.'])]]
# [[('FIS', 'FIS', ['NNP']),
#   ('in', 'in', ['IN']),
#   ('India', 'India', ['NNP']),
#   ('is', 'is', ['VBZ']),
#   ('proud', 'proud', ['positive', 'JJ']),
#   ('to', 'to', ['TO']),
#   ('announce', 'announce', ['VB']),
#   ('the', 'the', ['DT']),
#   ('successful', 'successful', ['positive', 'JJ']),
#   ('completion', 'completion', ['NN']),
#   ('of', 'of', ['IN']),
#   ('CODE', 'CODE', ['NNP']),
#   ('FEST', 'FEST', ['NNP']),
#   ('2022', '2022', ['CD']),
#   ('.', '.', ['.'])],
#  [('The', 'The', ['DT']),
#   ('event', 'event', ['NN']),
#   ('was', 'was', ['VBD']),
#   ('hosted', 'hosted', ['VBN']),
#   ('virtually', 'virtually', ['RB']),
#   ('over', 'over', ['IN']),
#   ('a', 'a', ['DT']),
#   ('period', 'period', ['NN']),
#   ('of', 'of', ['IN']),
#   ('two', 'two', ['CD']),
#   ('months', 'months', ['NNS']),
#   ('and', 'and', ['CC']),
#   ('1500', '1500', ['CD']),
#   ('participants', 'participants', ['NNS']),
#   ('worked', 'worked', ['positive', 'VBN']),
#   ('on', 'on', ['IN']),
#   ('specific', 'specific', ['JJ']),
#   ('challenges', 'challenges', ['NNS']),
#   ('and', 'and', ['CC']),
#   ('leveraged', 'leveraged', ['JJ']),
#   ('skills', 'skills', ['NNS']),
#   ('such', 'such', ['JJ']),
#   ('as', 'as', ['IN']),
#   ('Java', 'Java', ['NNP']),
#   ('and', 'and', ['CC']),
#   ('.Net', '.Net', ['NNP']),
#   ('to', 'to', ['TO']),
#   ('develop', 'develop', ['VB']),
#   ('innovative', 'innovative', ['positive', 'JJ']),
#   ('solutions', 'solutions', ['NNS']),
#   ('for', 'for', ['IN']),
#   ('the', 'the', ['DT']),
#   ('challenges', 'challenges', ['NNS']),
#   ('given', 'given', ['VBN']),
#   ('to', 'to', ['TO']),
#   ('them', 'them', ['PRP']),
#   ('.', '.', ['.'])],
#  [('We', 'We', ['PRP']),
#   ('had', 'had', ['VBD']),
#   ('100+', '100+', ['CD']),
#   ('coding', 'coding', ['NN']),
#   ('challenge', 'challenge', ['NN']),
#   ('qualifiers', 'qualifiers', ['NNS']),
#   ('from', 'from', ['IN']),
#   ('companies', 'companies', ['NNS']),
#   ('like', 'like', ['positive', 'IN']),
#   ('Google', 'Google', ['NNP']),
#   (',', ',', [',']),
#   ('Amazon', 'Amazon', ['NNP']),
#   (',', ',', [',']),
#   ('Adobe', 'Adobe', ['NNP']),
#   (',', ',', [',']),
#   ('Morgan', 'Morgan', ['NNP']),
#   ('Stanley', 'Stanley', ['NNP']),
#   (',', ',', [',']),
#   ('Walmart', 'Walmart', ['NNP']),
#   (',', ',', [',']),
#   ('KPMG', 'KPMG', ['NNP']),
#   (',', ',', [',']),
#   ('Credit', 'Credit', ['NNP']),
#   ('Suisse', 'Suisse', ['NNP']),
#   (',', ',', [',']),
#   ('Deloitte', 'Deloitte', ['NNP']),
#   (',', ',', [',']),
#   ('and', 'and', ['CC']),
#   ('Oracle', 'Oracle', ['NNP']),
#   (',', ',', [',']),
#   ('and', 'and', ['CC']),
#   ('the', 'the', ['DT']),
#   ('top', 'top', ['positive', 'JJ']),
#   ('3', '3', ['CD']),
#   ('winners', 'winners', ['positive', 'NNS']),
#   ('were', 'were', ['VBD']),
#   ('announced', 'announced', ['VBN']),
#   ('in', 'in', ['IN']),
#   ('a', 'a', ['DT']),
#   ('virtual', 'virtual', ['JJ']),
#   ('award', 'award', ['positive', 'NN']),
#   ('ceremony', 'ceremony', ['NN']),
#   ('in', 'in', ['IN']),
#   ('presence', 'presence', ['NN']),
#   ('of', 'of', ['IN']),
#   ('our', 'our', ['PRP$']),
#   ('leaders', 'leaders', ['NNS']),
#   ('.', '.', ['.'])],
#  [('Many', 'Many', ['JJ']),
#   ('congratulations', 'congratulations', ['positive', 'NNS']),
#   ('to', 'to', ['TO']),
#   ('all', 'all', ['PDT']),
#   ('the', 'the', ['DT']),
#   ('winners', 'winners', ['positive', 'NNS']),
#   ('and', 'and', ['CC']),
#   ('participants', 'participants', ['NNS']),
#   ('and', 'and', ['CC']),
#   ('special', 'special', ['JJ']),
#   ('thanks', 'thanks', ['NNS']),
#   ('to', 'to', ['TO']),
#   ('our', 'our', ['PRP$']),
#   ('event', 'event', ['NN']),
#   ('hosting', 'hosting', ['VBG']),
#   ('partner', 'partner', ['NN']),
#   ('Mercer', 'Mercer', ['NNP']),
#   ('Mettl', 'Mettl', ['NNP']),
#   ('and', 'and', ['CC']),
#   ('all', 'all', ['DT']),
#   ('our', 'our', ['PRP$']),
#   ('colleagues', 'colleagues', ['NNS']),
#   ('for', 'for', ['IN']),
#   ('their', 'their', ['PRP$']),
#   ('support', 'support', ['positive', 'NN']),
#   ('.', '.', ['.'])],
#  [('Meet', 'Meet', ['NNP']),
#   ('the', 'the', ['DT']),
#   ('winners', 'winners', ['positive', 'NNS']),
#   (':', ':', [':'])]]
# [[('Credit', 'Credit', ['NNP']),
#   ('Suisse', 'Suisse', ['NNP']),
#   ('Global', 'Global', ['NNP']),
#   ('Coding', 'Coding', ['NNP']),
#   ('Challenge', 'Challenge', ['NNP']),
#   ('Batch', 'Batch', ['NNP']),
#   (':', ':', [':']),
#   ('2022', '2022', ['CD']),
#   (',', ',', [',']),
#   ('2023', '2023', ['CD']),
#   (',', ',', [',']),
#   ('2024', '2024', ['CD']),
#   (',', ',', [',']),
#   ('2025', '2025', ['CD']),
#   (',', ',', [',']),
#   ('2026', '2026', ['CD']),
#   ('Intern/FTE', 'Intern/FTE', ['NNP']),
#   ('Offers', 'Offers', ['NNPS']),
#   ('Apply', 'Apply', ['NNP']),
#   (':', ':', [':']),
#   ('https', 'https', ['NN']),
#   (':', ':', [':']),
#   ('//lnkd.in/d87ZKNxp', '//lnkd.in/d87ZKNxp', ['NN'])]]
# [[('Hello', 'Hello', ['NNP']),
#   ('great', 'great', ['positive', 'JJ']),
#   ('people👐', 'people👐', ['NN']),
#   (',', ',', [',']),
#   ('Hope', 'Hope', ['NNP']),
#   ('you', 'you', ['PRP']),
#   ('all', 'all', ['DT']),
#   ('are', 'are', ['VBP']),
#   ('doing', 'doing', ['VBG']),
#   ('great😉', 'great😉', ['NNS']),
#   ('So', 'So', ['RB']),
#   (',', ',', [',']),
#   ('here', 'here', ['RB']),
#   ('are', 'are', ['VBP']),
#   ('some', 'some', ['DT']),
#   ('major', 'major', ['JJ']),
#   ('internships', 'internships', ['NNS']),
#   ('and', 'and', ['CC']),
#   ('open', 'open', ['JJ']),
#   ('source💜', 'source💜', ['NN']),
#   ('programs', 'programs', ['NNS']),
#   ('which', 'which', ['WDT']),
#   ('are', 'are', ['VBP']),
#   ('held', 'held', ['VBN']),
#   ('throughout', 'throughout', ['IN']),
#   ('the', 'the', ['DT']),
#   ('year', 'year', ['NN']),
#   ('in', 'in', ['IN']),
#   ('their', 'their', ['PRP$']),
#   ('respective', 'respective', ['JJ']),
#   ('timelines.🤩🤩🔥', 'timelines.🤩🤩🔥', ['NN']),
#   ('👉', '👉', ['$']),
#   ('30', '30', ['CD']),
#   ('Days', 'Days', ['NNP']),
#   ('of', 'of', ['IN']),
#   ('Google', 'Google', ['NNP']),
#   ('cloud', 'cloud', ['negative', 'NNP']),
#   ('by', 'by', ['IN']),
#   ('Google', 'Google', ['NNP']),
#   ('Adobe', 'Adobe', ['NNP']),
#   ('Analytics', 'Analytics', ['NNP']),
#   ('Challenge', 'Challenge', ['NNP']),
#   ('Adobe', 'Adobe', ['NNP']),
#   ('India', 'India', ['NNP']),
#   ('Women-in-Technology', 'Women-in-Technology', ['NNP']),
#   ('Scholarship', 'Scholarship', ['NNP']),
#   ('Advent', 'Advent', ['NNP']),
#   ('of', 'of', ['IN']),
#   ('Code', 'Code', ['NNP']),
#   ('Alexa', 'Alexa', ['NNP']),
#   ('prize', 'prize', ['positive', 'NNP']),
#   ('by', 'by', ['IN']),
#   ('Amazon', 'Amazon', ['NNP']),
#   ('Amazon', 'Amazon', ['NNP']),
#   ('wow', 'wow', ['positive', 'NNP']),
#   ('Bubble', 'Bubble', ['NNP']),
#   ('Cup', 'Cup', ['NNP']),
#   ('Capgemini', 'Capgemini', ['NNP']),
#   ('Tech', 'Tech', ['NNP']),
#   ('Challenge', 'Challenge', ['NNP']),
#   ('Code', 'Code', ['NNP']),
#   ('For', 'For', ['IN']),
#   ('good', 'good', ['positive', 'NNP']),
#   ('Code', 'Code', ['NNP']),
#   ('jam', 'jam', ['negative', 'NNP']),
#   ('by', 'by', ['IN']),
#   ('Google', 'Google', ['NNP']),
#   ('Code', 'Code', ['NNP']),
#   ('Gladiators', 'Gladiators', ['NNP']),
#   ('Code', 'Code', ['NNP']),
#   ('jam', 'jam', ['negative', 'NNP']),
#   ('to', 'to', ['TO']),
#   ('I/O', 'I/O', ['NNP']),
#   ('for', 'for', ['IN']),
#   ('Women', 'Women', ['NNP']),
#   ('Codechef', 'Codechef', ['NNP']),
#   ('SnackDown', 'SnackDown', ['NNP']),
#   ('Coderita', 'Coderita', ['NNP']),
#   ('2.0', '2.0', ['CD']),
#   ('by', 'by', ['IN']),
#   ('GeeksforGeeks', 'GeeksforGeeks', ['NNP']),
#   ('Codiva', 'Codiva', ['NNP']),
#   ('by', 'by', ['IN']),
#   ('Adobe', 'Adobe', ['NNP']),
#   ('Cook-off', 'Cook-off', ['NNP']),
#   ('by', 'by', ['IN']),
#   ('CodeChef', 'CodeChef', ['NNP']),
#   ('D.E', 'D.E', ['NNP']),
#   ('.', '.', ['.'])],
#  [('Shaw', 'Shaw', ['NNP']),
#   ('Mentorship', 'Mentorship', ['NNP']),
#   ('Program', 'Program', ['NNP']),
#   ('DevFest', 'DevFest', ['NNP']),
#   ('India', 'India', ['NNP']),
#   ('by', 'by', ['IN']),
#   ('Google', 'Google', ['NNP']),
#   ('Developers', 'Developers', ['NNP']),
#   ('Group', 'Group', ['NNP']),
#   ('Discovery', 'Discovery', ['NNP']),
#   ('Fellowship', 'Fellowship', ['NNP']),
#   ('e-Yantra', 'e-Yantra', ['JJ']),
#   ('Robotic', 'Robotic', ['NNP']),
#   ('Competition', 'Competition', ['NNP']),
#   ('by', 'by', ['IN']),
#   ('IIT', 'IIT', ['NNP']),
#   ('Bombay', 'Bombay', ['NNP']),
#   ('Flipkart', 'Flipkart', ['NNP']),
#   ('GRiD', 'GRiD', ['NNP']),
#   ('Flipkart', 'Flipkart', ['NNP']),
#   ('Runway', 'Runway', ['NNP']),
#   ('Flipr', 'Flipr', ['NNP']),
#   ('Hackathon', 'Hackathon', ['NNP']),
#   ('Generation', 'Generation', ['NNP']),
#   ('Google', 'Google', ['NNP']),
#   ('Scholarship', 'Scholarship', ['NNP']),
#   ('(', '(', ['(']),
#   ('Aisa', 'Aisa', ['NNP']),
#   ('Pacific', 'Pacific', ['NNP']),
#   (')', ')', [')']),
#   ('GirlScript', 'GirlScript', ['NNP']),
#   ('Summer', 'Summer', ['NNP']),
#   ('of', 'of', ['IN']),
#   ('Code', 'Code', ['NNP']),
#   ('GirlScript', 'GirlScript', ['NNP']),
#   ('Winter', 'Winter', ['NNP']),
#   ('of', 'of', ['IN']),
#   ('Contributing', 'Contributing', ['NNP']),
#   ('Github', 'Github', ['NNP']),
#   ('Campus', 'Campus', ['NNP']),
#   ('Expert', 'Expert', ['NNP']),
#   ('GoogleCloudReady', 'GoogleCloudReady', ['NNP']),
#   ('Facilitator', 'Facilitator', ['NNP']),
#   ('Program', 'Program', ['NNP']),
#   ('Google', 'Google', ['NNP']),
#   ('Capture', 'Capture', ['NNP']),
#   ('The', 'The', ['DT']),
#   ('Flag', 'Flag', ['NNP']),
#   ('Google', 'Google', ['NNP']),
#   ('Developer', 'Developer', ['NNP']),
#   ('Student', 'Student', ['NNP']),
#   ('Clubs', 'Clubs', ['NNP']),
#   ('Google', 'Google', ['NNP']),
#   ('Step', 'Step', ['NNP']),
#   ('Intern', 'Intern', ['NNP']),
#   ('Google', 'Google', ['NNP']),
#   ('Summer', 'Summer', ['NNP']),
#   ('of', 'of', ['IN']),
#   ('Code', 'Code', ['NNP']),
#   ('by', 'by', ['IN']),
#   ('Google', 'Google', ['NNP']),
#   ('Google', 'Google', ['NNP']),
#   ('Season', 'Season', ['NNP']),
#   ('of', 'of', ['IN']),
#   ('Docs', 'Docs', ['NNP']),
#   ('by', 'by', ['IN']),
#   ('Google', 'Google', ['NNP']),
#   ('Global', 'Global', ['NNP']),
#   ('Coding', 'Coding', ['NNP']),
#   ('Challenge', 'Challenge', ['NNP']),
#   ('by', 'by', ['IN']),
#   ('Credit', 'Credit', ['NNP']),
#   ('Suisse', 'Suisse', ['NNP']),
#   ('HackerCup', 'HackerCup', ['NNP']),
#   ('by', 'by', ['IN']),
#   ('Facebook', 'Facebook', ['NNP']),
#   ('Hacktoberfest', 'Hacktoberfest', ['NNP']),
#   ('by', 'by', ['IN']),
#   ('DigitalOcean', 'DigitalOcean', ['NNP']),
#   ('HackwithInfy', 'HackwithInfy', ['NNP']),
#   ('by', 'by', ['IN']),
#   ('Infosys', 'Infosys', ['NNP']),
#   ('Hash', 'Hash', ['NNP']),
#   ('code', 'code', ['NN']),
#   ('by', 'by', ['IN']),
#   ('Google', 'Google', ['NNP']),
#   ('HP', 'HP', ['NNP']),
#   ('CodeWars', 'CodeWars', ['NNP']),
#   ('Imagine', 'Imagine', ['NNP']),
#   ('Cup', 'Cup', ['NNP']),
#   ('by', 'by', ['IN']),
#   ('Microsoft', 'Microsoft', ['NNP']),
#   ('International', 'International', ['NNP']),
#   ('Collegiate', 'Collegiate', ['NNP']),
#   ('Programming', 'Programming', ['NNP']),
#   ('Contest', 'Contest', ['NNP']),
#   ('International', 'International', ['NNP']),
#   ('Conference', 'Conference', ['NNP']),
#   ('on', 'on', ['IN']),
#   ('Functional', 'Functional', ['NNP']),
#   ('Programming', 'Programming', ['NNP']),
#   ('Internet', 'Internet', ['NNP']),
#   ('problem', 'problem', ['negative', 'NNP']),
#   ('Solving', 'Solving', ['VBG']),
#   ('Contest', 'Contest', ['NNP']),
#   ('Intuit', 'Intuit', ['NNP']),
#   ('Augment', 'Augment', ['NNP']),
#   ('Kaggle', 'Kaggle', ['NNP']),
#   ('by', 'by', ['IN']),
#   ('Google', 'Google', ['NNP']),
#   ('Kick', 'Kick', ['NNP']),
#   ('start', 'start', ['NN']),
#   ('by', 'by', ['IN']),
#   ('Google', 'Google', ['NNP']),
#   ('Learn', 'Learn', ['NNP']),
#   ('to', 'to', ['TO']),
#   ('Earn', 'Earn', ['NNP']),
#   ('cloud', 'cloud', ['negative', 'NNP']),
#   ('Challenge', 'Challenge', ['NNP']),
#   ('LiFT', 'LiFT', ['NNP']),
#   ('Scholar', 'Scholar', ['NN']),
#   ('!', '!', ['.'])],
#  [('Linkedin', 'Linkedin', ['NNP']),
#   ('Wintathon', 'Wintathon', ['NNP']),
#   ('Lunchtime', 'Lunchtime', ['NNP']),
#   ('by', 'by', ['IN']),
#   ('Codechef', 'Codechef', ['NNP']),
#   ('master', 'master', ['positive', 'NNP']),
#   ('the', 'the', ['DT']),
#   ('Mainframe', 'Mainframe', ['NNP']),
#   ('by', 'by', ['IN']),
#   ('IBM', 'IBM', ['NNP']),
#   ('Microsoft', 'Microsoft', ['NNP']),
#   ('Codess', 'Codess', ['NNP']),
#   ('Microsoft', 'Microsoft', ['NNP']),
#   ('Engage', 'Engage', ['NNP']),
#   ('Program', 'Program', ['NNP']),
#   ('Microsoft', 'Microsoft', ['NNP']),
#   ('Learn', 'Learn', ['NNP']),
#   ('Student', 'Student', ['NNP']),
#   ('Ambassadors', 'Ambassadors', ['NNP']),
#   ('Mitacs', 'Mitacs', ['NNP']),
#   ('Globalink', 'Globalink', ['NNP']),
#   ('Research', 'Research', ['NNP']),
#   ('Internship', 'Internship', ['NNP']),
#   ('MLH', 'MLH', ['NNP']),
#   ('Fellowship', 'Fellowship', ['NNP']),
#   ('Myntra', 'Myntra', ['NNP']),
#   ('HackerRamp', 'HackerRamp', ['NNP']),
#   (':', ':', [':']),
#   ('WeForShe', 'WeForShe', ['NNP']),
#   ('Nanyang', 'Nanyang', ['NNP']),
#   ('Technological', 'Technological', ['NNP']),
#   ('University', 'University', ['NNP']),
#   ('(', '(', ['(']),
#   ('NTU', 'NTU', ['NNP']),
#   (')', ')', [')']),
#   ('–', '–', ['VBP']),
#   ('India', 'India', ['NNP']),
#   ('Connect', 'Connect', ['NNP']),
#   ('Nutanix', 'Nutanix', ['NNP']),
#   ('Heart', 'Heart', ['NNP']),
#   ('Women', 'Women', ['NNP']),
#   ('in', 'in', ['IN']),
#   ('Technology', 'Technology', ['NNP']),
#   ('Scholarships', 'Scholarships', ['NNP']),
#   ('Outreachy', 'Outreachy', ['NNP']),
#   ('Program', 'Program', ['NNP']),
#   ('SheCodes', 'SheCodes', ['NNP']),
#   ('by', 'by', ['IN']),
#   ('Accolite', 'Accolite', ['NNP']),
#   ('Digital', 'Digital', ['NNP']),
#   ('smart', 'smart', ['positive', 'NNP']),
#   ('India', 'India', ['NNP']),
#   ('Hackthon', 'Hackthon', ['NNP']),
#   ('by', 'by', ['IN']),
#   ('Govt', 'Govt', ['NNP']),
#   ('.', '.', ['.'])],
#  [('of', 'of', ['IN']),
#   ('India', 'India', ['NNP']),
#   ('Script', 'Script', ['NNP']),
#   ('Winter', 'Winter', ['NNP']),
#   ('of', 'of', ['IN']),
#   ('Code', 'Code', ['NNP']),
#   ('Solution', 'Solution', ['NNP']),
#   ('Challenge', 'Challenge', ['NNP']),
#   ('TopCoder', 'TopCoder', ['NNP']),
#   ('Open', 'Open', ['NNP']),
#   ('TCS', 'TCS', ['NNP']),
#   ('CodeVita', 'CodeVita', ['NNP']),
#   ('Uber', 'Uber', ['NNP']),
#   ('HackTag', 'HackTag', ['NNP']),
#   ('uplift', 'uplift', ['positive', 'NNP']),
#   ('Project', 'Project', ['NNP']),
#   ('Visa', 'Visa', ['NNP']),
#   ('Code', 'Code', ['NNP']),
#   ('UR', 'UR', ['NNP']),
#   ('Way', 'Way', ['NNP']),
#   ('Women', 'Women', ['NNP']),
#   ('Engineers', 'Engineers', ['NNP']),
#   ('Program', 'Program', ['NNP']),
#   ('👉', '👉', ['NNP']),
#   ('Do', 'Do', ['NNP']),
#   ('check', 'check', ['VB']),
#   ('them', 'them', ['PRP']),
#   ('out😉🙌🙌', 'out😉🙌🙌', ['RP'])]]
# [[('Hello', 'Hello', ['NNP']),
#   ('#', '#', ['#']),
#   ('connections', 'connections', ['NNS']),
#   (',', ',', [',']),
#   ('I', 'I', ['PRP']),
#   ('am', 'am', ['VBP']),
#   ('Ronak', 'Ronak', ['NNP']),
#   ('Jethava', 'Jethava', ['NNP']),
#   ('-', '-', [':']),
#   ('A', 'A', ['DT']),
#   ('final', 'final', ['JJ']),
#   ('year', 'year', ['NN']),
#   ('student', 'student', ['NN']),
#   ('at', 'at', ['IN']),
#   ('DAIICT', 'DAIICT', ['NNP']),
#   ('.', '.', ['.'])],
#  [('I', 'I', ['PRP']),
#   ('am', 'am', ['VBP']),
#   ('a', 'a', ['DT']),
#   ('good', 'good', ['positive', 'JJ']),
#   ('team', 'team', ['NN']),
#   ('player', 'player', ['NN']),
#   (',', ',', [',']),
#   ('a', 'a', ['DT']),
#   ('quick', 'quick', ['JJ']),
#   ('learner', 'learner', ['NN']),
#   (',', ',', [',']),
#   ('a', 'a', ['DT']),
#   ('problem', 'problem', ['negative', 'NN']),
#   ('solver', 'solver', ['NN']),
#   (',', ',', [',']),
#   ('and', 'and', ['CC']),
#   ('a', 'a', ['DT']),
#   ('person', 'person', ['NN']),
#   ('with', 'with', ['IN']),
#   ('good', 'good', ['positive', 'JJ']),
#   ('time-management', 'time-management', ['NN']),
#   (',', ',', [',']),
#   ('problem-solving', 'problem-solving', ['NN']),
#   (',', ',', [',']),
#   ('and', 'and', ['CC']),
#   ('communication', 'communication', ['NN']),
#   ('skills', 'skills', ['NNS']),
#   ('.', '.', ['.'])],
#  [('I', 'I', ['PRP']),
#   ('am', 'am', ['VBP']),
#   ('looking', 'looking', ['VBG']),
#   ('for', 'for', ['IN']),
#   ('a', 'a', ['DT']),
#   ('6-months', '6-months', ['JJ']),
#   ('(', '(', ['(']),
#   ('January-June', 'January-June', ['JJ']),
#   ('2023', '2023', ['CD']),
#   (')', ')', [')']),
#   ('winter', 'winter', ['NN']),
#   ('internship', 'internship', ['NN']),
#   ('to', 'to', ['TO']),
#   ('apply', 'apply', ['VB']),
#   ('my', 'my', ['PRP$']),
#   ('coding', 'coding', ['NN']),
#   ('and', 'and', ['CC']),
#   ('problem-solving', 'problem-solving', ['JJ']),
#   ('skills', 'skills', ['NNS']),
#   ('to', 'to', ['TO']),
#   ('a', 'a', ['DT']),
#   ('real-world', 'real-world', ['NN']),
#   ('project', 'project', ['NN']),
#   ('and', 'and', ['CC']),
#   ('to', 'to', ['TO']),
#   ('get', 'get', ['VB']),
#   ('good', 'good', ['positive', 'JJ']),
#   ('hands-on', 'hands-on', ['JJ']),
#   ('experience', 'experience', ['NN']),
#   ('with', 'with', ['IN']),
#   ('real-world', 'real-world', ['NN']),
#   ('project', 'project', ['NN']),
#   ('complexities', 'complexities', ['NNS']),
#   ('.', '.', ['.'])],
#  [('Here', 'Here', ['RB']),
#   ('are', 'are', ['VBP']),
#   ('some', 'some', ['DT']),
#   ('of', 'of', ['IN']),
#   ('my', 'my', ['PRP$']),
#   ('top', 'top', ['positive', 'JJ']),
#   ('achievements', 'achievements', ['positive', 'NNS']),
#   (':', ':', [':']),
#   ('-', '-', [':']),
#   ('>', '>', ['NN']),
#   ('HackWithInfy', 'HackWithInfy', ['NNP']),
#   ('2022', '2022', ['CD']),
#   ('Finalist', 'Finalist', ['NNP']),
#   ('-', '-', [':']),
#   ('>', '>', ['NN']),
#   ('Among', 'Among', ['IN']),
#   ('top', 'top', ['positive', 'JJ']),
#   ('10', '10', ['CD']),
#   ('in', 'in', ['IN']),
#   ('Akamai', 'Akamai', ['NNP']),
#   ('Edge', 'Edge', ['NNP']),
#   ('Hackathon', 'Hackathon', ['NNP']),
#   ('-', '-', [':']),
#   ('>', '>', ['JJ']),
#   ('Rank', 'Rank', ['NNP']),
#   ('of', 'of', ['IN']),
#   ('27', '27', ['CD']),
#   ('among', 'among', ['IN']),
#   ('27K', '27K', ['CD']),
#   ('coders', 'coders', ['NNS']),
#   ('in', 'in', ['IN']),
#   ('Global', 'Global', ['NNP']),
#   ('coding', 'coding', ['NN']),
#   ('challenge', 'challenge', ['NN']),
#   ('by', 'by', ['IN']),
#   ('Credit', 'Credit', ['NNP']),
#   ('Suisse', 'Suisse', ['NNP']),
#   ('-', '-', [':']),
#   ('>', '>', ['NN']),
#   ('Among', 'Among', ['IN']),
#   ('the', 'the', ['DT']),
#   ('top', 'top', ['positive', 'JJ']),
#   ('900', '900', ['CD']),
#   ('in', 'in', ['IN']),
#   ('Google', 'Google', ['NNP']),
#   ('Kickstart', 'Kickstart', ['NNP']),
#   ('round', 'round', ['VBD']),
#   ('C', 'C', ['NNP']),
#   ('of', 'of', ['IN']),
#   ('2022', '2022', ['CD']),
#   ('-', '-', [':']),
#   ('>', '>', ['NN']),
#   ('Among', 'Among', ['IN']),
#   ('the', 'the', ['DT']),
#   ('top', 'top', ['positive', 'JJ']),
#   ('2', '2', ['CD']),
#   ('%', '%', ['NN']),
#   ('in', 'in', ['IN']),
#   ('the', 'the', ['DT']),
#   ('leetcode', 'leetcode', ['NN']),
#   ('community', 'community', ['NN']),
#   ('-', '-', [':']),
#   ('>', '>', ['JJ']),
#   ('5-star', '5-star', ['JJ']),
#   ('coder', 'coder', ['NN']),
#   ('on', 'on', ['IN']),
#   ('CodeChef', 'CodeChef', ['NNP']),
#   ('with', 'with', ['IN']),
#   ('a', 'a', ['DT']),
#   ('max', 'max', ['NN']),
#   ('rating', 'rating', ['NN']),
#   ('of', 'of', ['IN']),
#   ('2154', '2154', ['CD']),
#   ('My', 'My', ['NNP']),
#   ('resume', 'resume', ['NN']),
#   ('is', 'is', ['VBZ']),
#   ('also', 'also', ['RB']),
#   ('attached', 'attached', ['VBN']),
#   ('to', 'to', ['TO']),
#   ('the', 'the', ['DT']),
#   ('post', 'post', ['NN']),
#   ('.', '.', ['.'])],
#  [('Let', 'Let', ['VB']),
#   ('me', 'me', ['PRP']),
#   ('know', 'know', ['VB']),
#   ('if', 'if', ['IN']),
#   ('you', 'you', ['PRP']),
#   ('have', 'have', ['VBP']),
#   ('any', 'any', ['DT']),
#   ('related', 'related', ['JJ']),
#   ('opportunity', 'opportunity', ['NN']),
#   ('or', 'or', ['CC']),
#   ('a', 'a', ['DT']),
#   ('referral', 'referral', ['JJ']),
#   ('!', '!', ['.']),
#   ('!', '!', ['.'])],
#  [('Please', 'Please', ['NNP']),
#   ('like/Share/Comment', 'like/Share/Comment', ['NN']),
#   ('for', 'for', ['IN']),
#   ('better', 'better', ['positive', 'JJR']),
#   ('reach', 'reach', ['NN']),
#   (':', ':', [':']),
#   ('>', '>', ['JJ']),
#   ('thank', 'thank', ['positive', 'NNP']),
#   ('you', 'you', ['PRP'])]]
# [[('Global', 'Global', ['JJ']),
#   ('Coding', 'Coding', ['NNP']),
#   ('champion', 'champion', ['positive', 'NN']),
#   ('!', '!', ['.'])],
#  [('Hi', 'Hi', ['NNP']),
#   ('Connections', 'Connections', ['NNP']),
#   (',', ',', [',']),
#   ('I', 'I', ['PRP']),
#   ('am', 'am', ['VBP']),
#   ('thrilled', 'thrilled', ['positive', 'VBN']),
#   ('to', 'to', ['TO']),
#   ('announce', 'announce', ['VB']),
#   ('that', 'that', ['IN']),
#   ('I', 'I', ['PRP']),
#   ('won', 'won', ['positive', 'VBD']),
#   ('the', 'the', ['DT']),
#   ('Global', 'Global', ['NNP']),
#   ('Coding', 'Coding', ['NNP']),
#   ('Challenge', 'Challenge', ['NNP']),
#   ('2021', '2021', ['CD']),
#   ('organized', 'organized', ['VBN']),
#   ('by', 'by', ['IN']),
#   ('.', '.', ['.'])],
#  [('The', 'The', ['DT']),
#   ('problems', 'problems', ['negative', 'NNS']),
#   ('were', 'were', ['VBD']),
#   ('fun', 'fun', ['positive', 'RB']),
#   (',', ',', [',']),
#   ('had', 'had', ['VBD']),
#   ('a', 'a', ['DT']),
#   ('great', 'great', ['positive', 'JJ']),
#   ('time', 'time', ['NN']),
#   ('trying', 'trying', ['VBG']),
#   ('to', 'to', ['TO']),
#   ('optimize', 'optimize', ['VB']),
#   ('my', 'my', ['PRP$']),
#   ('solutions', 'solutions', ['NNS']),
#   ('.', '.', ['.'])],
#  [('thank', 'thank', ['positive', 'NNP']),
#   ('you', 'you', ['PRP']),
#   ('for', 'for', ['IN']),
#   ('organizing', 'organizing', ['VBG']),
#   ('the', 'the', ['DT']),
#   ('contest', 'contest', ['NN']),
#   ('.', '.', ['.'])],
#  [('PS', 'PS', ['NN']),
#   (':', ':', [':']),
#   ('You', 'You', ['PRP']),
#   ('can', 'can', ['MD']),
#   ('find', 'find', ['VB']),
#   ('a', 'a', ['DT']),
#   ('link', 'link', ['NN']),
#   ('to', 'to', ['TO']),
#   ('my', 'my', ['PRP$']),
#   ('solutions', 'solutions', ['NNS']),
#   ('in', 'in', ['IN']),
#   ('the', 'the', ['DT']),
#   ('first', 'first', ['JJ']),
#   ('comment', 'comment', ['NN']),
#   ('.', '.', ['.'])]]
# [[('From', 'From', ['IN']),
#   ('getting', 'getting', ['VBG']),
#   ('disqualified', 'disqualified', ['VBN']),
#   ('for', 'for', ['IN']),
#   ('unknown', 'unknown', ['negative', 'JJ']),
#   ('reasons', 'reasons', ['NNS']),
#   (',', ',', [',']),
#   ('to', 'to', ['TO']),
#   ('landing', 'landing', ['VBG']),
#   ('in', 'in', ['IN']),
#   ('the', 'the', ['DT']),
#   ('second', 'second', ['JJ']),
#   ('position', 'position', ['NN']),
#   (',', ',', [',']),
#   ('the', 'the', ['DT']),
#   ('journey', 'journey', ['NN']),
#   ('wasn’t', 'wasn’t', ['NN']),
#   ('easy', 'easy', ['positive', 'JJ']),
#   ('but', 'but', ['CC']),
#   ('it', 'it', ['PRP']),
#   ('was', 'was', ['VBD']),
#   ('worth', 'worth', ['positive', 'JJ']),
#   ('it', 'it', ['PRP']),
#   ('at', 'at', ['IN']),
#   ('the', 'the', ['DT']),
#   ('end', 'end', ['NN']),
#   ('.', '.', ['.'])],
#  [('Sometimes', 'Sometimes', ['RB']),
#   ('you', 'you', ['PRP']),
#   ('got', 'got', ['VBD']),
#   ('ta', 'ta', ['JJ']),
#   ('fight', 'fight', ['NN']),
#   ('for', 'for', ['IN']),
#   ('something', 'something', ['NN']),
#   ('you', 'you', ['PRP']),
#   ('deserve', 'deserve', ['VBP']),
#   ('.', '.', ['.'])],
#  [('Hello', 'Hello', ['NNP']),
#   (',', ',', [',']),
#   ('Connections', 'Connections', ['NNP']),
#   ('.', '.', ['.'])],
#  [('I', 'I', ['PRP']),
#   ('hope', 'hope', ['VBP']),
#   ('you', 'you', ['PRP']),
#   ('are', 'are', ['VBP']),
#   ('doing', 'doing', ['VBG']),
#   ('well', 'well', ['positive', 'RB']),
#   ('.', '.', ['.'])],
#  [('Last', 'Last', ['JJ']),
#   ('year', 'year', ['NN']),
#   (',', ',', [',']),
#   ('I', 'I', ['PRP']),
#   ('won', 'won', ['positive', 'VBD']),
#   ('the', 'the', ['DT']),
#   ('Global', 'Global', ['NNP']),
#   ('Coding', 'Coding', ['NNP']),
#   ('Challenge', 'Challenge', ['NNP']),
#   ('organized', 'organized', ['VBN']),
#   ('by', 'by', ['IN']),
#   ('from', 'from', ['IN']),
#   ('the', 'the', ['DT']),
#   ('rest', 'rest', ['NN']),
#   ('of', 'of', ['IN']),
#   ('the', 'the', ['DT']),
#   ('world', 'world', ['NN']),
#   ('region', 'region', ['NN']),
#   (',', ',', [',']),
#   ('and', 'and', ['CC']),
#   ('this', 'this', ['DT']),
#   ('year', 'year', ['NN']),
#   ('I', 'I', ['PRP']),
#   ('landed', 'landed', ['VBD']),
#   ('in', 'in', ['IN']),
#   ('the', 'the', ['DT']),
#   ('second', 'second', ['JJ']),
#   ('position', 'position', ['NN']),
#   ('.', '.', ['.'])],
#  [('It', 'It', ['PRP']),
#   ('wasn’t', 'wasn’t', ['VBZ']),
#   ('easy', 'easy', ['positive', 'JJ']),
#   ('for', 'for', ['IN']),
#   ('me', 'me', ['PRP']),
#   ('because', 'because', ['IN']),
#   ('I', 'I', ['PRP']),
#   ('was', 'was', ['VBD']),
#   ('disqualified', 'disqualified', ['VBN']),
#   (',', ',', [',']),
#   ('as', 'as', ['IN']),
#   ('my', 'my', ['PRP$']),
#   ('solution', 'solution', ['NN']),
#   ('for', 'for', ['IN']),
#   ('problem', 'problem', ['negative', 'NN']),
#   ('4', '4', ['CD']),
#   ('matched', 'matched', ['VBN']),
#   ('with', 'with', ['IN']),
#   ('someone', 'someone', ['NN']),
#   ('else’s', 'else’s', ['NN']),
#   ('.', '.', ['.'])],
#  [('I', 'I', ['PRP']),
#   ('have', 'have', ['VBP']),
#   ('posted', 'posted', ['VBN']),
#   ('my', 'my', ['PRP$']),
#   ('solution', 'solution', ['NN']),
#   ('as', 'as', ['RB']),
#   ('well', 'well', ['positive', 'RB']),
#   ('here', 'here', ['RB']),
#   ('.', '.', ['.'])],
#  [('Finally', 'Finally', ['RB']),
#   (',', ',', [',']),
#   ('I', 'I', ['PRP']),
#   ('would', 'would', ['MD']),
#   ('like', 'like', ['positive', 'VB']),
#   ('to', 'to', ['TO']),
#   ('congratulate', 'congratulate', ['positive', 'VB']),
#   ('my', 'my', ['PRP$']),
#   ('friend', 'friend', ['NN']),
#   ('and', 'and', ['CC']),
#   ('am', 'am', ['VBP']),
#   ('glad', 'glad', ['positive', 'VBN']),
#   ('to', 'to', ['TO']),
#   ('share', 'share', ['NN']),
#   ('that', 'that', ['IN']),
#   ('the', 'the', ['DT']),
#   ('top', 'top', ['positive', 'JJ']),
#   ('two', 'two', ['CD']),
#   ('positions', 'positions', ['NNS']),
#   ('are', 'are', ['VBP']),
#   ('from', 'from', ['IN']),
#   ('.', '.', ['.'])],
#  [('congratulations', 'congratulations', ['positive', 'NNS']),
#   ('to', 'to', ['TO']),
#   ('us', 'us', ['PRP']),
#   ('!', '!', ['.']),
#   ('!', '!', ['.'])],
#  [('!', '!', ['.'])]]
# [[('Received', 'Received', ['VBN']),
#   ('my', 'my', ['PRP$']),
#   ('goodies', 'goodies', ['NNS']),
#   ('today', 'today', ['NN']),
#   ('from', 'from', ['IN']),
#   ('Credit', 'Credit', ['NNP']),
#   ('Suisse', 'Suisse', ['NNP']),
#   ('.', '.', ['.'])],
#  [('Ranked', 'Ranked', ['VBN']),
#   ('within', 'within', ['IN']),
#   ('top', 'top', ['positive', 'JJ']),
#   ('200', '200', ['CD']),
#   ('in', 'in', ['IN']),
#   ('the', 'the', ['DT']),
#   ('Global', 'Global', ['NNP']),
#   ('Coding', 'Coding', ['NNP']),
#   ('Challenge', 'Challenge', ['NNP']),
#   ('2021', '2021', ['CD']),
#   ('organised', 'organised', ['VBN']),
#   ('by', 'by', ['IN']),
#   ('Credit', 'Credit', ['NNP']),
#   ('Suisse', 'Suisse', ['NNP']),
#   ('.', '.', ['.'])],
#  [('thank', 'thank', ['positive', 'NNP']),
#   ('you', 'you', ['PRP']),
#   ('so much', 'so much', ['inc']),
#   ('for', 'for', ['IN']),
#   ('these', 'these', ['DT']),
#   ('goodies', 'goodies', ['NNS']),
#   ('and', 'and', ['CC']),
#   ('encouraging', 'encouraging', ['positive', 'VBG']),
#   ('young', 'young', ['JJ']),
#   ('talent', 'talent', ['positive', 'NN']),
#   ('.', '.', ['.'])],
#  [('Once', 'Once', ['RB']),
#   ('again', 'again', ['RB']),
#   ('thanks', 'thanks', ['NNS']),
#   ('to', 'to', ['TO']),
#   ('Striver', 'Striver', ['NNP']),
#   ('whom', 'whom', ['WP']),
#   ('I', 'I', ['PRP']),
#   ('admire', 'admire', ['positive', 'VBP']),
#   ('-', '-', [':']),
#   ('have', 'have', ['VBP']),
#   ('learnt', 'learnt', ['VBN']),
#   ('a', 'a', ['DT']),
#   ('lot', 'lot', ['NN']),
#   ('from', 'from', ['IN']),
#   ('your', 'your', ['PRP$']),
#   ('videos', 'videos', ['NNS']),
#   (':', ':', [':']),
#   ('D', 'D', ['NN'])]]
# [[('#', '#', ['#']),
#   ('globalcodingchallenge', 'globalcodingchallenge', ['NN']),
#   ('#', '#', ['#']),
#   ('gcc', 'gcc', ['JJ']),
#   ('#', '#', ['#']),
#   ('creditsuisse', 'creditsuisse', ['JJ']),
#   ('Voila', 'Voila', ['NN']),
#   ('!', '!', ['.'])],
#  [('Join', 'Join', ['VB']),
#   ('me', 'me', ['PRP']),
#   ('on', 'on', ['IN']),
#   ('the', 'the', ['DT']),
#   ('Global', 'Global', ['NNP']),
#   ('Coding', 'Coding', ['NNP']),
#   ('Challenge', 'Challenge', ['NNP']),
#   ('a', 'a', ['DT']),
#   ('3', '3', ['CD']),
#   ('week', 'week', ['NN']),
#   ('Coding', 'Coding', ['NNP']),
#   ('Competition', 'Competition', ['NNP']),
#   ('organized', 'organized', ['VBN']),
#   ('by', 'by', ['IN']),
#   ('Credit', 'Credit', ['NNP']),
#   ('Suisse', 'Suisse', ['NNP']),
#   ('and', 'and', ['CC']),
#   ('get', 'get', ['VB']),
#   ('a', 'a', ['DT']),
#   ('chance', 'chance', ['NN']),
#   ('to', 'to', ['TO']),
#   ('compete', 'compete', ['VB']),
#   ('with', 'with', ['IN']),
#   ('great', 'great', ['positive', 'JJ']),
#   ('people', 'people', ['NNS']),
#   ('and', 'and', ['CC']),
#   ('win', 'win', ['positive', 'VB']),
#   ('some', 'some', ['DT']),
#   ('cool', 'cool', ['positive', 'JJ']),
#   ('prizes', 'prizes', ['NNS']),
#   ('!', '!', ['.']),
#   ('!', '!', ['.'])],
#  [('Scan', 'Scan', ['JJ']),
#   ('this', 'this', ['DT']),
#   ('QR', 'QR', ['NNP']),
#   ('Code', 'Code', ['NNP']),
#   ('and', 'and', ['CC']),
#   ('enter', 'enter', ['VBP']),
#   ('the', 'the', ['DT']),
#   ('contest', 'contest', ['NN']),
#   ('.', '.', ['.'])],
#  [('While', 'While', ['IN']),
#   ('registering', 'registering', ['VBG']),
#   ('do', 'do', ['VBP']),
#   ('use', 'use', ['VB']),
#   ('my', 'my', ['PRP$']),
#   ('Promo', 'Promo', ['NNP']),
#   ('Code', 'Code', ['NNP']),
#   ("-'WillOfHeaven", "-'WillOfHeaven", ['NNP']),
#   ("'", "'", ['POS'])]]
# [[('FIS', 'FIS', ['NNP']),
#   ('in', 'in', ['IN']),
#   ('India', 'India', ['NNP']),
#   ('is', 'is', ['VBZ']),
#   ('proud', 'proud', ['positive', 'JJ']),
#   ('to', 'to', ['TO']),
#   ('announce', 'announce', ['VB']),
#   ('the', 'the', ['DT']),
#   ('successful', 'successful', ['positive', 'JJ']),
#   ('completion', 'completion', ['NN']),
#   ('of', 'of', ['IN']),
#   ('CODE', 'CODE', ['NNP']),
#   ('FEST', 'FEST', ['NNP']),
#   ('2022', '2022', ['CD']),
#   ('.', '.', ['.'])],
#  [('The', 'The', ['DT']),
#   ('event', 'event', ['NN']),
#   ('was', 'was', ['VBD']),
#   ('hosted', 'hosted', ['VBN']),
#   ('virtually', 'virtually', ['RB']),
#   ('over', 'over', ['IN']),
#   ('a', 'a', ['DT']),
#   ('period', 'period', ['NN']),
#   ('of', 'of', ['IN']),
#   ('two', 'two', ['CD']),
#   ('months', 'months', ['NNS']),
#   ('and', 'and', ['CC']),
#   ('1500', '1500', ['CD']),
#   ('participants', 'participants', ['NNS']),
#   ('worked', 'worked', ['positive', 'VBN']),
#   ('on', 'on', ['IN']),
#   ('specific', 'specific', ['JJ']),
#   ('challenges', 'challenges', ['NNS']),
#   ('and', 'and', ['CC']),
#   ('leveraged', 'leveraged', ['JJ']),
#   ('skills', 'skills', ['NNS']),
#   ('such', 'such', ['JJ']),
#   ('as', 'as', ['IN']),
#   ('Java', 'Java', ['NNP']),
#   ('and', 'and', ['CC']),
#   ('.Net', '.Net', ['NNP']),
#   ('to', 'to', ['TO']),
#   ('develop', 'develop', ['VB']),
#   ('innovative', 'innovative', ['positive', 'JJ']),
#   ('solutions', 'solutions', ['NNS']),
#   ('for', 'for', ['IN']),
#   ('the', 'the', ['DT']),
#   ('challenges', 'challenges', ['NNS']),
#   ('given', 'given', ['VBN']),
#   ('to', 'to', ['TO']),
#   ('them', 'them', ['PRP']),
#   ('.', '.', ['.'])],
#  [('We', 'We', ['PRP']),
#   ('had', 'had', ['VBD']),
#   ('100+', '100+', ['CD']),
#   ('coding', 'coding', ['NN']),
#   ('challenge', 'challenge', ['NN']),
#   ('qualifiers', 'qualifiers', ['NNS']),
#   ('from', 'from', ['IN']),
#   ('companies', 'companies', ['NNS']),
#   ('like', 'like', ['positive', 'IN']),
#   ('Google', 'Google', ['NNP']),
#   (',', ',', [',']),
#   ('Amazon', 'Amazon', ['NNP']),
#   (',', ',', [',']),
#   ('Adobe', 'Adobe', ['NNP']),
#   (',', ',', [',']),
#   ('Morgan', 'Morgan', ['NNP']),
#   ('Stanley', 'Stanley', ['NNP']),
#   (',', ',', [',']),
#   ('Walmart', 'Walmart', ['NNP']),
#   (',', ',', [',']),
#   ('KPMG', 'KPMG', ['NNP']),
#   (',', ',', [',']),
#   ('Credit', 'Credit', ['NNP']),
#   ('Suisse', 'Suisse', ['NNP']),
#   (',', ',', [',']),
#   ('Deloitte', 'Deloitte', ['NNP']),
#   (',', ',', [',']),
#   ('and', 'and', ['CC']),
#   ('Oracle', 'Oracle', ['NNP']),
#   (',', ',', [',']),
#   ('and', 'and', ['CC']),
#   ('the', 'the', ['DT']),
#   ('top', 'top', ['positive', 'JJ']),
#   ('3', '3', ['CD']),
#   ('winners', 'winners', ['positive', 'NNS']),
#   ('were', 'were', ['VBD']),
#   ('announced', 'announced', ['VBN']),
#   ('in', 'in', ['IN']),
#   ('a', 'a', ['DT']),
#   ('virtual', 'virtual', ['JJ']),
#   ('award', 'award', ['positive', 'NN']),
#   ('ceremony', 'ceremony', ['NN']),
#   ('in', 'in', ['IN']),
#   ('presence', 'presence', ['NN']),
#   ('of', 'of', ['IN']),
#   ('our', 'our', ['PRP$']),
#   ('leaders', 'leaders', ['NNS']),
#   ('.', '.', ['.'])],
#  [('Many', 'Many', ['JJ']),
#   ('congratulations', 'congratulations', ['positive', 'NNS']),
#   ('to', 'to', ['TO']),
#   ('all', 'all', ['PDT']),
#   ('the', 'the', ['DT']),
#   ('winners', 'winners', ['positive', 'NNS']),
#   ('and', 'and', ['CC']),
#   ('participants', 'participants', ['NNS']),
#   ('and', 'and', ['CC']),
#   ('special', 'special', ['JJ']),
#   ('thanks', 'thanks', ['NNS']),
#   ('to', 'to', ['TO']),
#   ('our', 'our', ['PRP$']),
#   ('event', 'event', ['NN']),
#   ('hosting', 'hosting', ['VBG']),
#   ('partner', 'partner', ['NN']),
#   ('Mercer', 'Mercer', ['NNP']),
#   ('Mettl', 'Mettl', ['NNP']),
#   ('and', 'and', ['CC']),
#   ('all', 'all', ['DT']),
#   ('our', 'our', ['PRP$']),
#   ('colleagues', 'colleagues', ['NNS']),
#   ('for', 'for', ['IN']),
#   ('their', 'their', ['PRP$']),
#   ('support', 'support', ['positive', 'NN']),
#   ('.', '.', ['.'])],
#  [('Meet', 'Meet', ['NNP']),
#   ('the', 'the', ['DT']),
#   ('winners', 'winners', ['positive', 'NNS']),
#   (':', ':', [':'])]]
# [[('FIS', 'FIS', ['NNP']),
#   ('in', 'in', ['IN']),
#   ('India', 'India', ['NNP']),
#   ('is', 'is', ['VBZ']),
#   ('proud', 'proud', ['positive', 'JJ']),
#   ('to', 'to', ['TO']),
#   ('announce', 'announce', ['VB']),
#   ('the', 'the', ['DT']),
#   ('successful', 'successful', ['positive', 'JJ']),
#   ('completion', 'completion', ['NN']),
#   ('of', 'of', ['IN']),
#   ('CODE', 'CODE', ['NNP']),
#   ('FEST', 'FEST', ['NNP']),
#   ('2022', '2022', ['CD']),
#   ('.', '.', ['.'])],
#  [('The', 'The', ['DT']),
#   ('event', 'event', ['NN']),
#   ('was', 'was', ['VBD']),
#   ('hosted', 'hosted', ['VBN']),
#   ('virtually', 'virtually', ['RB']),
#   ('over', 'over', ['IN']),
#   ('a', 'a', ['DT']),
#   ('period', 'period', ['NN']),
#   ('of', 'of', ['IN']),
#   ('two', 'two', ['CD']),
#   ('months', 'months', ['NNS']),
#   ('and', 'and', ['CC']),
#   ('1500', '1500', ['CD']),
#   ('participants', 'participants', ['NNS']),
#   ('worked', 'worked', ['positive', 'VBN']),
#   ('on', 'on', ['IN']),
#   ('specific', 'specific', ['JJ']),
#   ('challenges', 'challenges', ['NNS']),
#   ('and', 'and', ['CC']),
#   ('leveraged', 'leveraged', ['JJ']),
#   ('skills', 'skills', ['NNS']),
#   ('such', 'such', ['JJ']),
#   ('as', 'as', ['IN']),
#   ('Java', 'Java', ['NNP']),
#   ('and', 'and', ['CC']),
#   ('.Net', '.Net', ['NNP']),
#   ('to', 'to', ['TO']),
#   ('develop', 'develop', ['VB']),
#   ('innovative', 'innovative', ['positive', 'JJ']),
#   ('solutions', 'solutions', ['NNS']),
#   ('for', 'for', ['IN']),
#   ('the', 'the', ['DT']),
#   ('challenges', 'challenges', ['NNS']),
#   ('given', 'given', ['VBN']),
#   ('to', 'to', ['TO']),
#   ('them', 'them', ['PRP']),
#   ('.', '.', ['.'])],
#  [('We', 'We', ['PRP']),
#   ('had', 'had', ['VBD']),
#   ('100+', '100+', ['CD']),
#   ('coding', 'coding', ['NN']),
#   ('challenge', 'challenge', ['NN']),
#   ('qualifiers', 'qualifiers', ['NNS']),
#   ('from', 'from', ['IN']),
#   ('companies', 'companies', ['NNS']),
#   ('like', 'like', ['positive', 'IN']),
#   ('Google', 'Google', ['NNP']),
#   (',', ',', [',']),
#   ('Amazon', 'Amazon', ['NNP']),
#   (',', ',', [',']),
#   ('Adobe', 'Adobe', ['NNP']),
#   (',', ',', [',']),
#   ('Morgan', 'Morgan', ['NNP']),
#   ('Stanley', 'Stanley', ['NNP']),
#   (',', ',', [',']),
#   ('Walmart', 'Walmart', ['NNP']),
#   (',', ',', [',']),
#   ('KPMG', 'KPMG', ['NNP']),
#   (',', ',', [',']),
#   ('Credit', 'Credit', ['NNP']),
#   ('Suisse', 'Suisse', ['NNP']),
#   (',', ',', [',']),
#   ('Deloitte', 'Deloitte', ['NNP']),
#   (',', ',', [',']),
#   ('and', 'and', ['CC']),
#   ('Oracle', 'Oracle', ['NNP']),
#   (',', ',', [',']),
#   ('and', 'and', ['CC']),
#   ('the', 'the', ['DT']),
#   ('top', 'top', ['positive', 'JJ']),
#   ('3', '3', ['CD']),
#   ('winners', 'winners', ['positive', 'NNS']),
#   ('were', 'were', ['VBD']),
#   ('announced', 'announced', ['VBN']),
#   ('in', 'in', ['IN']),
#   ('a', 'a', ['DT']),
#   ('virtual', 'virtual', ['JJ']),
#   ('award', 'award', ['positive', 'NN']),
#   ('ceremony', 'ceremony', ['NN']),
#   ('in', 'in', ['IN']),
#   ('presence', 'presence', ['NN']),
#   ('of', 'of', ['IN']),
#   ('our', 'our', ['PRP$']),
#   ('leaders', 'leaders', ['NNS']),
#   ('.', '.', ['.'])],
#  [('Many', 'Many', ['JJ']),
#   ('congratulations', 'congratulations', ['positive', 'NNS']),
#   ('to', 'to', ['TO']),
#   ('all', 'all', ['PDT']),
#   ('the', 'the', ['DT']),
#   ('winners', 'winners', ['positive', 'NNS']),
#   ('and', 'and', ['CC']),
#   ('participants', 'participants', ['NNS']),
#   ('and', 'and', ['CC']),
#   ('special', 'special', ['JJ']),
#   ('thanks', 'thanks', ['NNS']),
#   ('to', 'to', ['TO']),
#   ('our', 'our', ['PRP$']),
#   ('event', 'event', ['NN']),
#   ('hosting', 'hosting', ['VBG']),
#   ('partner', 'partner', ['NN']),
#   ('Mercer', 'Mercer', ['NNP']),
#   ('Mettl', 'Mettl', ['NNP']),
#   ('and', 'and', ['CC']),
#   ('all', 'all', ['DT']),
#   ('our', 'our', ['PRP$']),
#   ('colleagues', 'colleagues', ['NNS']),
#   ('for', 'for', ['IN']),
#   ('their', 'their', ['PRP$']),
#   ('support', 'support', ['positive', 'NN']),
#   ('.', '.', ['.'])],
#  [('Meet', 'Meet', ['NNP']),
#   ('the', 'the', ['DT']),
#   ('winners', 'winners', ['positive', 'NNS']),
#   (':', ':', [':'])]]
# [[('Finally', 'Finally', ['RB']),
#   ('an', 'an', ['DT']),
#   ('all', 'all', ['DT']),
#   ('nighter', 'nighter', ['JJ']),
#   ('pays', 'pays', ['NNS']),
#   ('off', 'off', ['IN']),
#   ('!', '!', ['.'])],
#  [('After', 'After', ['IN']),
#   ('25', '25', ['CD']),
#   ('hours', 'hours', ['NNS']),
#   ('of', 'of', ['IN']),
#   ('coding', 'coding', ['NN']),
#   (',', ',', [',']),
#   ('along', 'along', ['IN']),
#   ('with', 'with', ['IN']),
#   ('joint', 'joint', ['JJ']),
#   ('efforts', 'efforts', ['NNS']),
#   ('of', 'of', ['IN']),
#   ('Abdulwadood', 'Abdulwadood', ['NNP']),
#   ('Ashraf', 'Ashraf', ['NNP']),
#   ('Faazli', 'Faazli', ['NNP']),
#   ('and', 'and', ['CC']),
#   (',', ',', [',']),
#   ('we', 'we', ['PRP']),
#   ('were', 'were', ['VBD']),
#   ('able', 'able', ['JJ']),
#   ('to', 'to', ['TO']),
#   ('pull', 'pull', ['VB']),
#   ('of', 'of', ['IN']),
#   ('a', 'a', ['DT']),
#   ('second', 'second', ['JJ']),
#   ('runner', 'runner', ['NN']),
#   ('up', 'up', ['RP']),
#   ('at', 'at', ['IN']),
#   ('2022-CodeIT', '2022-CodeIT', ['JJ']),
#   ('-', '-', [':']),
#   ('Credit', 'Credit', ['NNP']),
#   ('Suisse', 'Suisse', ['NNP']),
#   ('Challenge', 'Challenge', ['NNP']),
#   ('.', '.', ['.'])],
#  [('thank', 'thank', ['positive', 'NNP']),
#   ('you', 'you', ['PRP']),
#   ('for', 'for', ['IN']),
#   ('providing', 'providing', ['VBG']),
#   ('us', 'us', ['PRP']),
#   ('with', 'with', ['IN']),
#   ('this', 'this', ['DT']),
#   ('amazing', 'amazing', ['positive', 'JJ']),
#   ('opportunity', 'opportunity', ['NN']),
#   ('to', 'to', ['TO']),
#   ('use', 'use', ['VB']),
#   ('our', 'our', ['PRP$']),
#   ('skills', 'skills', ['NNS']),
#   ('and', 'and', ['CC']),
#   ('to', 'to', ['TO']),
#   ('learn', 'learn', ['VB']),
#   ('and', 'and', ['CC']),
#   ('grow', 'grow', ['VB']),
#   ('more', 'more', ['JJR']),
#   ('.', '.', ['.'])]]
# [[('FIS', 'FIS', ['NNP']),
#   ('in', 'in', ['IN']),
#   ('India', 'India', ['NNP']),
#   ('is', 'is', ['VBZ']),
#   ('proud', 'proud', ['positive', 'JJ']),
#   ('to', 'to', ['TO']),
#   ('announce', 'announce', ['VB']),
#   ('the', 'the', ['DT']),
#   ('successful', 'successful', ['positive', 'JJ']),
#   ('completion', 'completion', ['NN']),
#   ('of', 'of', ['IN']),
#   ('CODE', 'CODE', ['NNP']),
#   ('FEST', 'FEST', ['NNP']),
#   ('2022', '2022', ['CD']),
#   ('.', '.', ['.'])],
#  [('The', 'The', ['DT']),
#   ('event', 'event', ['NN']),
#   ('was', 'was', ['VBD']),
#   ('hosted', 'hosted', ['VBN']),
#   ('virtually', 'virtually', ['RB']),
#   ('over', 'over', ['IN']),
#   ('a', 'a', ['DT']),
#   ('period', 'period', ['NN']),
#   ('of', 'of', ['IN']),
#   ('two', 'two', ['CD']),
#   ('months', 'months', ['NNS']),
#   ('and', 'and', ['CC']),
#   ('1500', '1500', ['CD']),
#   ('participants', 'participants', ['NNS']),
#   ('worked', 'worked', ['positive', 'VBN']),
#   ('on', 'on', ['IN']),
#   ('specific', 'specific', ['JJ']),
#   ('challenges', 'challenges', ['NNS']),
#   ('and', 'and', ['CC']),
#   ('leveraged', 'leveraged', ['JJ']),
#   ('skills', 'skills', ['NNS']),
#   ('such', 'such', ['JJ']),
#   ('as', 'as', ['IN']),
#   ('Java', 'Java', ['NNP']),
#   ('and', 'and', ['CC']),
#   ('.Net', '.Net', ['NNP']),
#   ('to', 'to', ['TO']),
#   ('develop', 'develop', ['VB']),
#   ('innovative', 'innovative', ['positive', 'JJ']),
#   ('solutions', 'solutions', ['NNS']),
#   ('for', 'for', ['IN']),
#   ('the', 'the', ['DT']),
#   ('challenges', 'challenges', ['NNS']),
#   ('given', 'given', ['VBN']),
#   ('to', 'to', ['TO']),
#   ('them', 'them', ['PRP']),
#   ('.', '.', ['.'])],
#  [('We', 'We', ['PRP']),
#   ('had', 'had', ['VBD']),
#   ('100+', '100+', ['CD']),
#   ('coding', 'coding', ['NN']),
#   ('challenge', 'challenge', ['NN']),
#   ('qualifiers', 'qualifiers', ['NNS']),
#   ('from', 'from', ['IN']),
#   ('companies', 'companies', ['NNS']),
#   ('like', 'like', ['positive', 'IN']),
#   ('Google', 'Google', ['NNP']),
#   (',', ',', [',']),
#   ('Amazon', 'Amazon', ['NNP']),
#   (',', ',', [',']),
#   ('Adobe', 'Adobe', ['NNP']),
#   (',', ',', [',']),
#   ('Morgan', 'Morgan', ['NNP']),
#   ('Stanley', 'Stanley', ['NNP']),
#   (',', ',', [',']),
#   ('Walmart', 'Walmart', ['NNP']),
#   (',', ',', [',']),
#   ('KPMG', 'KPMG', ['NNP']),
#   (',', ',', [',']),
#   ('Credit', 'Credit', ['NNP']),
#   ('Suisse', 'Suisse', ['NNP']),
#   (',', ',', [',']),
#   ('Deloitte', 'Deloitte', ['NNP']),
#   (',', ',', [',']),
#   ('and', 'and', ['CC']),
#   ('Oracle', 'Oracle', ['NNP']),
#   (',', ',', [',']),
#   ('and', 'and', ['CC']),
#   ('the', 'the', ['DT']),
#   ('top', 'top', ['positive', 'JJ']),
#   ('3', '3', ['CD']),
#   ('winners', 'winners', ['positive', 'NNS']),
#   ('were', 'were', ['VBD']),
#   ('announced', 'announced', ['VBN']),
#   ('in', 'in', ['IN']),
#   ('a', 'a', ['DT']),
#   ('virtual', 'virtual', ['JJ']),
#   ('award', 'award', ['positive', 'NN']),
#   ('ceremony', 'ceremony', ['NN']),
#   ('in', 'in', ['IN']),
#   ('presence', 'presence', ['NN']),
#   ('of', 'of', ['IN']),
#   ('our', 'our', ['PRP$']),
#   ('leaders', 'leaders', ['NNS']),
#   ('.', '.', ['.'])],
#  [('Many', 'Many', ['JJ']),
#   ('congratulations', 'congratulations', ['positive', 'NNS']),
#   ('to', 'to', ['TO']),
#   ('all', 'all', ['PDT']),
#   ('the', 'the', ['DT']),
#   ('winners', 'winners', ['positive', 'NNS']),
#   ('and', 'and', ['CC']),
#   ('participants', 'participants', ['NNS']),
#   ('and', 'and', ['CC']),
#   ('special', 'special', ['JJ']),
#   ('thanks', 'thanks', ['NNS']),
#   ('to', 'to', ['TO']),
#   ('our', 'our', ['PRP$']),
#   ('event', 'event', ['NN']),
#   ('hosting', 'hosting', ['VBG']),
#   ('partner', 'partner', ['NN']),
#   ('Mercer', 'Mercer', ['NNP']),
#   ('Mettl', 'Mettl', ['NNP']),
#   ('and', 'and', ['CC']),
#   ('all', 'all', ['DT']),
#   ('our', 'our', ['PRP$']),
#   ('colleagues', 'colleagues', ['NNS']),
#   ('for', 'for', ['IN']),
#   ('their', 'their', ['PRP$']),
#   ('support', 'support', ['positive', 'NN']),
#   ('.', '.', ['.'])],
#  [('Meet', 'Meet', ['NNP']),
#   ('the', 'the', ['DT']),
#   ('winners', 'winners', ['positive', 'NNS']),
#   (':', ':', [':'])]]
# [[('FIS', 'FIS', ['NNP']),
#   ('in', 'in', ['IN']),
#   ('India', 'India', ['NNP']),
#   ('is', 'is', ['VBZ']),
#   ('proud', 'proud', ['positive', 'JJ']),
#   ('to', 'to', ['TO']),
#   ('announce', 'announce', ['VB']),
#   ('the', 'the', ['DT']),
#   ('successful', 'successful', ['positive', 'JJ']),
#   ('completion', 'completion', ['NN']),
#   ('of', 'of', ['IN']),
#   ('CODE', 'CODE', ['NNP']),
#   ('FEST', 'FEST', ['NNP']),
#   ('2022', '2022', ['CD']),
#   ('.', '.', ['.'])],
#  [('The', 'The', ['DT']),
#   ('event', 'event', ['NN']),
#   ('was', 'was', ['VBD']),
#   ('hosted', 'hosted', ['VBN']),
#   ('virtually', 'virtually', ['RB']),
#   ('over', 'over', ['IN']),
#   ('a', 'a', ['DT']),
#   ('period', 'period', ['NN']),
#   ('of', 'of', ['IN']),
#   ('two', 'two', ['CD']),
#   ('months', 'months', ['NNS']),
#   ('and', 'and', ['CC']),
#   ('1500', '1500', ['CD']),
#   ('participants', 'participants', ['NNS']),
#   ('worked', 'worked', ['positive', 'VBN']),
#   ('on', 'on', ['IN']),
#   ('specific', 'specific', ['JJ']),
#   ('challenges', 'challenges', ['NNS']),
#   ('and', 'and', ['CC']),
#   ('leveraged', 'leveraged', ['JJ']),
#   ('skills', 'skills', ['NNS']),
#   ('such', 'such', ['JJ']),
#   ('as', 'as', ['IN']),
#   ('Java', 'Java', ['NNP']),
#   ('and', 'and', ['CC']),
#   ('.Net', '.Net', ['NNP']),
#   ('to', 'to', ['TO']),
#   ('develop', 'develop', ['VB']),
#   ('innovative', 'innovative', ['positive', 'JJ']),
#   ('solutions', 'solutions', ['NNS']),
#   ('for', 'for', ['IN']),
#   ('the', 'the', ['DT']),
#   ('challenges', 'challenges', ['NNS']),
#   ('given', 'given', ['VBN']),
#   ('to', 'to', ['TO']),
#   ('them', 'them', ['PRP']),
#   ('.', '.', ['.'])],
#  [('We', 'We', ['PRP']),
#   ('had', 'had', ['VBD']),
#   ('100+', '100+', ['CD']),
#   ('coding', 'coding', ['NN']),
#   ('challenge', 'challenge', ['NN']),
#   ('qualifiers', 'qualifiers', ['NNS']),
#   ('from', 'from', ['IN']),
#   ('companies', 'companies', ['NNS']),
#   ('like', 'like', ['positive', 'IN']),
#   ('Google', 'Google', ['NNP']),
#   (',', ',', [',']),
#   ('Amazon', 'Amazon', ['NNP']),
#   (',', ',', [',']),
#   ('Adobe', 'Adobe', ['NNP']),
#   (',', ',', [',']),
#   ('Morgan', 'Morgan', ['NNP']),
#   ('Stanley', 'Stanley', ['NNP']),
#   (',', ',', [',']),
#   ('Walmart', 'Walmart', ['NNP']),
#   (',', ',', [',']),
#   ('KPMG', 'KPMG', ['NNP']),
#   (',', ',', [',']),
#   ('Credit', 'Credit', ['NNP']),
#   ('Suisse', 'Suisse', ['NNP']),
#   (',', ',', [',']),
#   ('Deloitte', 'Deloitte', ['NNP']),
#   (',', ',', [',']),
#   ('and', 'and', ['CC']),
#   ('Oracle', 'Oracle', ['NNP']),
#   (',', ',', [',']),
#   ('and', 'and', ['CC']),
#   ('the', 'the', ['DT']),
#   ('top', 'top', ['positive', 'JJ']),
#   ('3', '3', ['CD']),
#   ('winners', 'winners', ['positive', 'NNS']),
#   ('were', 'were', ['VBD']),
#   ('announced', 'announced', ['VBN']),
#   ('in', 'in', ['IN']),
#   ('a', 'a', ['DT']),
#   ('virtual', 'virtual', ['JJ']),
#   ('award', 'award', ['positive', 'NN']),
#   ('ceremony', 'ceremony', ['NN']),
#   ('in', 'in', ['IN']),
#   ('presence', 'presence', ['NN']),
#   ('of', 'of', ['IN']),
#   ('our', 'our', ['PRP$']),
#   ('leaders', 'leaders', ['NNS']),
#   ('.', '.', ['.'])],
#  [('Many', 'Many', ['JJ']),
#   ('congratulations', 'congratulations', ['positive', 'NNS']),
#   ('to', 'to', ['TO']),
#   ('all', 'all', ['PDT']),
#   ('the', 'the', ['DT']),
#   ('winners', 'winners', ['positive', 'NNS']),
#   ('and', 'and', ['CC']),
#   ('participants', 'participants', ['NNS']),
#   ('and', 'and', ['CC']),
#   ('special', 'special', ['JJ']),
#   ('thanks', 'thanks', ['NNS']),
#   ('to', 'to', ['TO']),
#   ('our', 'our', ['PRP$']),
#   ('event', 'event', ['NN']),
#   ('hosting', 'hosting', ['VBG']),
#   ('partner', 'partner', ['NN']),
#   ('Mercer', 'Mercer', ['NNP']),
#   ('Mettl', 'Mettl', ['NNP']),
#   ('and', 'and', ['CC']),
#   ('all', 'all', ['DT']),
#   ('our', 'our', ['PRP$']),
#   ('colleagues', 'colleagues', ['NNS']),
#   ('for', 'for', ['IN']),
#   ('their', 'their', ['PRP$']),
#   ('support', 'support', ['positive', 'NN']),
#   ('.', '.', ['.'])],
#  [('Meet', 'Meet', ['NNP']),
#   ('the', 'the', ['DT']),
# ...
#   ('leaders', 'leaders', ['NNS']),
#   ('are', 'are', ['VBP']),
#   ('not', 'not', ['inv', 'RB']),
#   ('scared', 'scared', ['negative', 'VBN']),
#   ('to', 'to', ['TO']),
#   ('make', 'make', ['VB']),
#   ('mistakes.“', 'mistakes.“', ['JJ']),
#   ('-', '-', [':']),
#   ('Gerry', 'Gerry', ['NNP']),
#   ('Poirier', 'Poirier', ['NNP']),
#   ('On', 'On', ['IN']),
#   ('the', 'the', ['DT']),
#   ('Schmooze', 'Schmooze', ['NNP']),
#   ('podcast', 'podcast', ['NN']),
#   ('features', 'features', ['NNS']),
#   ('interviews', 'interviews', ['NNS']),
#   ('with', 'with', ['IN']),
#   ('talented', 'talented', ['positive', 'JJ']),
#   ('professionals', 'professionals', ['NNS']),
#   ('who', 'who', ['WP']),
#   ('have', 'have', ['VBP']),
#   ('achieved', 'achieved', ['VBN']),
#   ('success', 'success', ['positive', 'NN']),
#   ('in', 'in', ['IN']),
#   ('their', 'their', ['PRP$']),
#   ('field', 'field', ['NN']),
#   ('or', 'or', ['CC']),
#   ('industry', 'industry', ['NN']),
#   ('.', '.', ['.'])],
#  [('They', 'They', ['PRP']),
#   ('share', 'share', ['NN']),
#   ('untold', 'untold', ['JJ']),
#   ('stories', 'stories', ['NNS']),
#   ('about', 'about', ['IN']),
#   ('their', 'their', ['PRP$']),
#   ('leadership', 'leadership', ['NN']),
#   ('journey', 'journey', ['NN']),
#   ('and', 'and', ['CC']),
#   ('how', 'how', ['WRB']),
#   ('they', 'they', ['PRP']),
#   ('built', 'built', ['VBD']),
#   ('and', 'and', ['CC']),
#   ('sustained', 'sustained', ['VBD']),
#   ('their', 'their', ['PRP$']),
#   ('professional', 'professional', ['JJ']),
#   ('network', 'network', ['NN']),
#   ('.', '.', ['.'])]]
# [[('#', '#', ['#']),
#   ('codingchallenge', 'codingchallenge', ['NN']),
#   ('#', '#', ['#']),
#   ('internshipopportunity', 'internshipopportunity', ['NN'])]]
# [[('What', 'What', ['WP']),
#   ('we', 'we', ['PRP']),
#   ("'re", "'re", ['VBP']),
#   ('working', 'working', ['VBG']),
#   ('on', 'on', ['IN']),
#   ('at', 'at', ['IN']),
#   ('MayStreet', 'MayStreet', ['NNP']),
#   ('-', '-', [':']),
#   ('the', 'the', ['DT']),
#   ('modern', 'modern', ['positive', 'JJ']),
#   ('market', 'market', ['NN']),
#   ('data', 'data', ['NNS']),
#   ('platform', 'platform', ['NN']),
#   ('.', '.', ['.'])]]
# [[('excited', 'excited', ['positive', 'VBN']),
#   ('to', 'to', ['TO']),
#   ('publish', 'publish', ['VB']),
#   ('this', 'this', ['DT']),
#   ('final', 'final', ['JJ']),
#   ('installment', 'installment', ['NN']),
#   ('on', 'on', ['IN']),
#   ('``', '``', ['``']),
#   ('The', 'The', ['DT']),
#   ('Future', 'Future', ['NN']),
#   ('of', 'of', ['IN']),
#   ('Banking', 'Banking', ['NN']),
#   (':', ':', [':']),
#   ('AI', 'AI', ['NNP']),
#   (',', ',', [',']),
#   ('Automation', 'Automation', ['NNP']),
#   ('&', '&', ['CC']),
#   ('the', 'the', ['DT']),
#   ('Creation', 'Creation', ['NN']),
#   ('of', 'of', ['IN']),
#   ('Meaning-Filled', 'Meaning-Filled', ['JJ']),
#   ('work', 'work', ['positive', 'NN']),
#   ('.', '.', ['.']),
#   ("''", "''", ["''"])],
#  [('My', 'My', ['PRP$']),
#   ('hope', 'hope', ['NN']),
#   ('is', 'is', ['VBZ']),
#   ('that', 'that', ['IN']),
#   ('even', 'even', ['RB']),
#   ('non-banking', 'non-banking', ['JJ']),
#   ('folks', 'folks', ['NNS']),
#   ('can', 'can', ['MD']),
#   ('walk', 'walk', ['VB']),
#   ('away', 'away', ['RB']),
#   ('from', 'from', ['IN']),
#   ('reading', 'reading', ['VBG']),
#   ('this', 'this', ['DT']),
#   ('piece', 'piece', ['NN']),
#   ('with', 'with', ['IN']),
#   ('a', 'a', ['DT']),
#   ('new', 'new', ['JJ']),
#   ('understanding', 'understanding', ['NN']),
#   ('of', 'of', ['IN']),
#   ('the', 'the', ['DT']),
#   ('future', 'future', ['NN']),
#   ('of', 'of', ['IN']),
#   ('banking-', 'banking-', ['JJ']),
#   ('I', 'I', ['PRP']),
#   ("'ve", "'ve", ['VBP']),
#   ('also', 'also', ['RB']),
#   ('included', 'included', ['VBN']),
#   ('some', 'some', ['DT']),
#   ('interactive', 'interactive', ['JJ']),
#   ('media', 'media', ['NNS']),
#   ('!', '!', ['.'])]]
# [[('thank', 'thank', ['positive', 'NNP']),
#   ('you', 'you', ['PRP']),
#   ('all', 'all', ['DT']),
#   ('for', 'for', ['IN']),
#   ('celebrating', 'celebrating', ['VBG']),
#   ('Juneteenth', 'Juneteenth', ['NNP']),
#   ('with', 'with', ['IN']),
#   ('us', 'us', ['PRP']),
#   ('(', '(', ['(']),
#   ('Keith', 'Keith', ['NNP']),
#   ('and', 'and', ['CC']),
#   ('I', 'I', ['PRP']),
#   ('and', 'and', ['CC']),
#   ('the', 'the', ['DT']),
#   ('CF', 'CF', ['NNP']),
#   ('BERG', 'BERG', ['NNP']),
#   ('Team', 'Team', ['NNP']),
#   (')', ')', [')']),
#   (',', ',', [',']),
#   ('please', 'please', ['VB']),
#   ('check', 'check', ['VB']),
#   ('out', 'out', ['RP']),
#   ('the', 'the', ['DT']),
#   ('article', 'article', ['NN']),
#   ('to', 'to', ['TO']),
#   ('learn', 'learn', ['VB']),
#   ('how', 'how', ['WRB']),
#   ('the', 'the', ['DT']),
#   ('Cross', 'Cross', ['NN']),
#   ('Firms', 'Firms', ['NNP']),
#   ('Black', 'Black', ['NNP']),
#   ('Employee', 'Employee', ['NNP']),
#   ('Resource', 'Resource', ['NNP']),
#   ('Group', 'Group', ['NNP']),
#   ('convened', 'convened', ['VBD']),
#   ('thousands', 'thousands', ['NNS']),
#   ('of', 'of', ['IN']),
#   ('finance', 'finance', ['NN']),
#   ('professionals', 'professionals', ['NNS']),
#   ('to', 'to', ['TO']),
#   ('move', 'move', ['VB']),
#   ('beyond', 'beyond', ['IN']),
#   ('discussion', 'discussion', ['NN']),
#   ('to', 'to', ['TO']),
#   ('action', 'action', ['NN']),
#   ('.', '.', ['.'])],
#  [('thank', 'thank', ['positive', 'NNP']),
#   ('you', 'you', ['PRP']),
#   ('to', 'to', ['TO']),
#   ('our', 'our', ['PRP$']),
#   ('amazing', 'amazing', ['positive', 'JJ']),
#   ('speakers', 'speakers', ['NNS']),
#   ('and', 'and', ['CC']),
#   ('moderators', 'moderators', ['NNS']),
#   (':', ':', [':']),
#   ('Speakers', 'Speakers', ['NNS']),
#   (':', ':', [':']),
#   ('Ainka', 'Ainka', ['NNP']),
#   ('Munroe', 'Munroe', ['NNP']),
#   ('-', '-', [':']),
#   ('equitable', 'equitable', ['positive', 'JJ']),
#   ('Advisors', 'Advisors', ['NNS']),
#   (',', ',', [',']),
#   ('Benin', 'Benin', ['NNP']),
#   ('Saffo', 'Saffo', ['NNP']),
#   ('-', '-', [':']),
#   ('IBM', 'IBM', ['NNP']),
#   ('Watson', 'Watson', ['NNP']),
#   (',', ',', [',']),
#   ('Megan', 'Megan', ['NNP']),
#   ('Hogan', 'Hogan', ['NNP']),
#   ('-', '-', [':']),
#   ('Goldman', 'Goldman', ['NNP']),
#   ('Sachs', 'Sachs', ['NNP']),
#   (',', ',', [',']),
#   ('-', '-', [':']),
#   ('AllianceBernstein', 'AllianceBernstein', ['NNP']),
#   (',', ',', [',']),
#   ('Claire', 'Claire', ['NNP']),
#   ('Green-Forde', 'Green-Forde', ['NNP']),
#   ('-', '-', [':']),
#   ('National', 'National', ['NNP']),
#   ('Association', 'Association', ['NNP']),
#   ('of', 'of', ['IN']),
#   ('Social', 'Social', ['NNP']),
#   ('Workers', 'Workers', ['NNP']),
#   (',', ',', [',']),
#   ('Sheena', 'Sheena', ['NNP']),
#   ('Wright', 'Wright', ['NNP']),
#   ('-', '-', [':']),
#   ('United', 'United', ['NNP']),
#   ('Way', 'Way', ['NNP']),
#   ('of', 'of', ['IN']),
#   ('New', 'New', ['NNP']),
#   ('York', 'York', ['NNP']),
#   ('City', 'City', ['NNP']),
#   ('Moderators', 'Moderators', ['NNS']),
#   (':', ':', [':']),
#   ('-', '-', [':']),
#   ('YJLaurent', 'YJLaurent', ['NN']),
#   ('Consulting', 'Consulting', ['NN']),
#   ('and', 'and', ['CC']),
#   ('-', '-', [':']),
#   ('Barclays', 'Barclays', ['NNP']),
#   ('Finally', 'Finally', ['NNP']),
#   (',', ',', [',']),
#   ('Big', 'Big', ['NNP']),
#   ('thank', 'thank', ['positive', 'NNP']),
#   ('You', 'You', ['PRP']),
#   ('to', 'to', ['TO']),
#   ('the', 'the', ['DT']),
#   ('Sponsoring', 'Sponsoring', ['JJ']),
#   ('Firms', 'Firms', ['NNS']),
#   ('of', 'of', ['IN']),
#   ('the', 'the', ['DT']),
#   ('2nd', '2nd', ['CD']),
#   ('Annual', 'Annual', ['NNP']),
#   ('CF', 'CF', ['NNP']),
#   ('BERG', 'BERG', ['NNP']),
#   ('Juneteenth', 'Juneteenth', ['NNP']),
#   ('celebration', 'celebration', ['positive', 'NNP']),
#   (':', ':', [':']),
#   (',', ',', [',']),
#   (',', ',', [',']),
#   (',', ',', [',']),
#   (',', ',', [',']),
#   (',', ',', [',']),
#   (',', ',', [',']),
#   (',', ',', [',']),
#   (',', ',', [',']),
#   (',', ',', [',']),
#   (',', ',', [',']),
#   (',', ',', [',']),
#   (',', ',', [',']),
#   (',', ',', [',']),
#   (',', ',', [',']),
#   ('.', '.', ['.']),
#   (',', ',', [',']),
#   (',', ',', [',']),
#   (',', ',', [',']),
#   (',', ',', [',']),
#   (',', ',', [','])]]
# [[('This', 'This', ['DT']),
#   ('is', 'is', ['VBZ']),
#   ('an', 'an', ['DT']),
#   ('interesting', 'interesting', ['positive', 'JJ']),
#   ('time', 'time', ['NN']),
#   ('to', 'to', ['TO']),
#   ('be', 'be', ['VB']),
#   ('alive', 'alive', ['JJ']),
#   ('.', '.', ['.'])],
#  [('Our', 'Our', ['PRP$']),
#   ('pandemic', 'pandemic', ['NN']),
#   ('has', 'has', ['VBZ']),
#   ('accelerated', 'accelerated', ['VBN']),
#   ('a', 'a', ['DT']),
#   ('reckoning', 'reckoning', ['VBG']),
#   ('with', 'with', ['IN']),
#   ('our', 'our', ['PRP$']),
#   ('broken', 'broken', ['negative', 'JJ']),
#   ('systems', 'systems', ['NNS']),
#   ('that', 'that', ['WDT']),
#   ('has', 'has', ['VBZ']),
#   ('been', 'been', ['VBN']),
#   ('on', 'on', ['IN']),
#   ('its', 'its', ['PRP$']),
#   ('way', 'way', ['NN']),
#   ('for', 'for', ['IN']),
#   ('a', 'a', ['DT']),
#   ('long', 'long', ['JJ']),
#   ('time', 'time', ['NN']),
#   ('.', '.', ['.'])],
#  [('#', '#', ['#']),
#   ('healthcare', 'healthcare', ['NN']),
#   ('#', '#', ['#']),
#   ('financialmarkets', 'financialmarkets', ['NNS'])]]
# [[('What', 'What', ['WP']),
#   ('your', 'your', ['PRP$']),
#   ('regulator', 'regulator', ['NN']),
#   ('might', 'might', ['MD']),
#   ('be', 'be', ['VB']),
#   ('about', 'about', ['IN']),
#   ('to', 'to', ['TO']),
#   ('ask', 'ask', ['VB']),
#   ('you', 'you', ['PRP']),
#   ('about', 'about', ['IN']),
#   ('your', 'your', ['PRP$']),
#   ('systems', 'systems', ['NNS']),
#   ('and', 'and', ['CC']),
#   ('controls', 'controls', ['NNS']),
#   ('-', '-', [':']),
#   ('even', 'even', ['RB']),
#   ('if', 'if', ['IN']),
#   ('you', 'you', ['PRP']),
#   ('do', 'do', ['VBP']),
#   ("n't", "n't", ['RB']),
#   ('trade', 'trade', ['VB']),
#   ('Oil', 'Oil', ['NNP']),
#   ('...', '...', [':']),
#   ('.', '.', ['.']),
#   ('#', '#', ['#']),
#   ('thiveonchange', 'thiveonchange', ['NN']),
#   ('#', '#', ['#']),
#   ('riskandcompliance', 'riskandcompliance', ['NN']),
#   ('#', '#', ['#']),
#   ('cco', 'cco', ['NN']),
#   ('#', '#', ['#']),
#   ('regulatorycompliance', 'regulatorycompliance', ['NN']),
#   ('#', '#', ['#']),
#   ('oilprice', 'oilprice', ['NN'])]]
# [[('What', 'What', ['WP']),
#   ('your', 'your', ['PRP$']),
#   ('regulator', 'regulator', ['NN']),
#   ('might', 'might', ['MD']),
#   ('be', 'be', ['VB']),
#   ('about', 'about', ['IN']),
#   ('to', 'to', ['TO']),
#   ('ask', 'ask', ['VB']),
#   ('you', 'you', ['PRP']),
#   ('about', 'about', ['IN']),
#   ('systems', 'systems', ['NNS']),
#   ('and', 'and', ['CC']),
#   ('controls', 'controls', ['NNS']),
#   ('-', '-', [':']),
#   ('even', 'even', ['RB']),
#   ('if', 'if', ['IN']),
#   ('you', 'you', ['PRP']),
#   ('dont', 'dont', ['VBP']),
#   ('trade', 'trade', ['VB']),
#   ('Oil', 'Oil', ['NNP']),
#   ('.', '.', ['.'])],
#  [('#', '#', ['#']),
#   ('thiveonchange', 'thiveonchange', ['NN']),
#   ('#', '#', ['#']),
#   ('riskandcompliance', 'riskandcompliance', ['NN']),
#   ('#', '#', ['#']),
#   ('cco', 'cco', ['NN']),
#   ('#', '#', ['#']),
#   ('regulatorycompliance', 'regulatorycompliance', ['NN']),
#   ('#', '#', ['#']),
#   ('oil', 'oil', ['NN']),
#   ('#', '#', ['#']),
#   ('dxctechnology', 'dxctechnology', ['NN']),
#   ('#', '#', ['#']),
#   ('cios', 'cios', ['NNS']),
#   ('#', '#', ['#']),
#   ('ctos', 'ctos', ['NNS'])]]
# [[('It', 'It', ['PRP']),
#   ("'s", "'s", ['VBZ']),
#   ('been', 'been', ['VBN']),
#   ('a', 'a', ['DT']),
#   ('challenging', 'challenging', ['negative', 'JJ']),
#   ('start', 'start', ['NN']),
#   ('to', 'to', ['TO']),
#   ('2020', '2020', ['CD']),
#   ('for', 'for', ['IN']),
#   ('...', '...', [':']),
#   ('well', 'well', ['positive', 'RB']),
#   (',', ',', [',']),
#   ('everyone', 'everyone', ['NN']),
#   (',', ',', [',']),
#   ('really', 'really', ['inc', 'RB']),
#   ('!', '!', ['.'])],
#  [('However', 'However', ['RB']),
#   (',', ',', [',']),
#   ('the', 'the', ['DT']),
#   ('oil', 'oil', ['NN']),
#   ('and', 'and', ['CC']),
#   ('gas', 'gas', ['NN']),
#   ('industry', 'industry', ['NN']),
#   ('has', 'has', ['VBZ']),
#   ('faced', 'faced', ['VBN']),
#   ('a', 'a', ['DT']),
#   ('particularly', 'particularly', ['RB']),
#   ('troubled', 'troubled', ['negative', 'JJ']),
#   ('time', 'time', ['NN']),
#   ('.', '.', ['.'])],
#  [('As', 'As', ['IN']),
#   ('these', 'these', ['DT']),
#   ('periods', 'periods', ['NNS']),
#   ('of', 'of', ['IN']),
#   ('instability', 'instability', ['negative', 'NN']),
#   ('become', 'become', ['VBN']),
#   ('more', 'more', ['RBR']),
#   ('regular', 'regular', ['JJ']),
#   ('for', 'for', ['IN']),
#   ('our', 'our', ['PRP$']),
#   ('industry', 'industry', ['NN']),
#   (',', ',', [',']),
#   ('operators', 'operators', ['NNS']),
#   ('must', 'must', ['MD']),
#   ('look', 'look', ['VB']),
#   ('for', 'for', ['IN']),
#   ('ways', 'ways', ['NNS']),
#   ('to', 'to', ['TO']),
#   ('mitigate', 'mitigate', ['VB']),
#   ('the', 'the', ['DT']),
#   ('worst', 'worst', ['negative', 'JJS']),
#   ('impact', 'impact', ['NN']),
#   ('.', '.', ['.'])],
#  [('Here', 'Here', ['RB']),
#   ('are', 'are', ['VBP']),
#   ('some', 'some', ['DT']),
#   ('of', 'of', ['IN']),
#   ('the', 'the', ['DT']),
#   ('top', 'top', ['positive', 'JJ']),
#   ('features', 'features', ['NNS']),
#   ('I', 'I', ['PRP']),
#   ('think', 'think', ['VBP']),
#   ('will', 'will', ['MD']),
#   ('help', 'help', ['VB']),
#   ('you', 'you', ['PRP']),
#   ('navigate', 'navigate', ['VB']),
#   ('the', 'the', ['DT']),
#   ('new-norm', 'new-norm', ['NN']),
#   ('.', '.', ['.'])]]
# [[('In', 'In', ['IN']),
#   ('Today', 'Today', ['NNP']),
#   ("'s", "'s", ['POS']),
#   ('complex', 'complex', ['negative', 'NNP']),
#   ('World', 'World', ['NNP']),
#   ('.', '.', ['.'])],
#  [('There', 'There', ['EX']),
#   ('are', 'are', ['VBP']),
#   ('a', 'a', ['DT']),
#   ('lot', 'lot', ['NN']),
#   ('of', 'of', ['IN']),
#   ('forces', 'forces', ['NNS']),
#   ('that', 'that', ['WDT']),
#   ('tend', 'tend', ['VBP']),
#   ('to', 'to', ['TO']),
#   ('sow', 'sow', ['VB']),
#   ('division', 'division', ['NN']),
#   ('and', 'and', ['CC']),
#   ('others', 'others', ['NNS']),
#   ('trying', 'trying', ['VBG']),
#   ('to', 'to', ['TO']),
#   ('be', 'be', ['VB']),
#   ('hypocritic', 'hypocritic', ['JJ']),
#   ('about', 'about', ['IN']),
#   ('finding', 'finding', ['VBG']),
#   ('common', 'common', ['JJ']),
#   ('grounds', 'grounds', ['NNS']),
#   ('.', '.', ['.'])],
#  [('Every', 'Every', ['DT']),
#   ('side', 'side', ['NN']),
#   ('has', 'has', ['VBZ']),
#   ('its', 'its', ['PRP$']),
#   ('pitfalls', 'pitfalls', ['NNS']),
#   ('and', 'and', ['CC']),
#   ('strength', 'strength', ['NN']),
#   ('.', '.', ['.'])],
#  [('In', 'In', ['IN']),
#   ('This', 'This', ['DT']),
#   ('Article', 'Article', ['NNP']),
#   (',', ',', [',']),
#   ('Political', 'Political', ['NNP']),
#   ('Philosopher', 'Philosopher', ['NNP']),
#   ('Chiara', 'Chiara', ['NNP']),
#   ('Cordelli', 'Cordelli', ['NNP']),
#   ('proposes', 'proposes', ['VBZ']),
#   ('a', 'a', ['DT']),
#   ('predicament', 'predicament', ['negative', 'NN']),
#   ('.', '.', ['.'])]]
# [[('A', 'A', ['DT']),
#   ('recent', 'recent', ['JJ']),
#   ('article', 'article', ['NN']),
#   ('by', 'by', ['IN']),
#   ('me', 'me', ['PRP']),
#   ('on', 'on', ['IN']),
#   ("'Pleading", "'Pleading", ['VBG']),
#   ('and', 'and', ['CC']),
#   ('proving', 'proving', ['positive', 'VBG']),
#   ('fraud', 'fraud', ['negative', 'NNP']),
#   ("'", "'", ['POS']),
#   ('which', 'which', ['WDT']),
#   ('I', 'I', ['PRP']),
#   ('hope', 'hope', ['VBP']),
#   ('people', 'people', ['NNS']),
#   ('will', 'will', ['MD']),
#   ('find', 'find', ['VB']),
#   ('useful', 'useful', ['positive', 'JJ']),
#   ('.', '.', ['.'])],
#  [('#', '#', ['#']),
#   ('fraud', 'fraud', ['negative', 'NN']),
#   ('#', '#', ['#']),
#   ('civilfraud', 'civilfraud', ['NN']),
#   ('#', '#', ['#']),
#   ('commerciallitigation', 'commerciallitigation', ['NN'])]]
# [[('#', '#', ['#']),
#   ('lowcode', 'lowcode', ['JJ']),
#   ('#', '#', ['#']),
#   ('nocode', 'nocode', ['JJ']),
#   ('#', '#', ['#']),
#   ('4gl', '4gl', ['CD']),
#   ('#', '#', ['#']),
#   ('sdlc', 'sdlc', ['JJ']),
#   ('#', '#', ['#']),
#   ('development', 'development', ['NN']),
#   ('#', '#', ['#']),
#   ('applicationbuild', 'applicationbuild', ['JJ']),
#   ('#', '#', ['#']),
#   ('userdevelopment', 'userdevelopment', ['JJ']),
#   ('#', '#', ['#']),
#   ('softwaredevelopment', 'softwaredevelopment', ['JJ']),
#   ('#', '#', ['#']),
#   ('coding', 'coding', ['VBG']),
#   ('#', '#', ['#']),
#   ('projectmanagment', 'projectmanagment', ['JJ']),
#   ('#', '#', ['#']),
#   ('softwaredelivery', 'softwaredelivery', ['JJ']),
#   ('#', '#', ['#']),
#   ('rachaelevans', 'rachaelevans', ['NNS'])]]

# %%
sentiment_df = pd.DataFrame(sentiment_array, columns=['Sentiment Score'])
sentiment_df.to_csv('creditS_scores.csv')

# %%
sentiment_df
# Out:
#    Sentiment Score
# 0         Positive
# 1    Very Positive
# 2          Neutral
# 3         Positive
# 4    Very Positive
# ..             ...
# 64         Neutral
# 65        Negative
# 66        Negative
# 67         Neutral
# 68         Neutral
#
# [69 rows x 1 columns]
